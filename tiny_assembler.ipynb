# %% [markdown]
# # Assembler per principle of computing in Jack, Hack

# %%
from lib.assembler import AssemblyExamples, print_with_lines, Assembler, Machine

assembly_example = AssemblyExamples.mult_nat # sumfive #simple_memory

print('Assembly code')
print('='*30)
print_with_lines(assembly_example)
print('='*30)
# Out:
# Assembly code
# ==============================
# 0  :
# 1  : // mult_nat(a, b) = b + mult_nat(a-1, B)
# 2  : // a = 3
# 3  : @3
# 4  : D=A
# 5  : @a
# 6  : M=D
# 7  : // b = 4
# 8  : @4
# 9  : D=A
# 10 : @b
# 11 : M=D
# 12 : // output = 0
# 13 : @0
# 14 : D=A
# 15 : @output
# 16 : M=D
# 17 : (LOOP)
# 18 :     // return if a == 0
# 19 :     @a
# 20 :     D=M
# 21 :     @END
# 22 :     D;JEQ
# 23 :     // a -= 1
# 24 :     @a
# 25 :     M=M-1
# 26 :     // output += b
# 27 :     @b
# 28 :     D=M
# 29 :     @output
# 30 :     M=D+M
# 31 :     @LOOP
# 32 :     0;JMP
# 33 : (END)
# 34 :
# ==============================

# %%
### translate assembly to machine code
ass = Assembler()
machine_codes, ass_linenos = ass(assembly_example)

print('Machine code')
print('='*30)
print_with_lines(machine_codes)
print('='*30)

### execute machine code
machine = Machine(verbose=True)
machine(machine_codes, ass_linenos)
# Out:
# Machine code
# ==============================
# 0  : 0000000000000011
# 1  : 1110110000010000
# 2  : 0000000000010000
# 3  : 1110001100001000
# 4  : 0000000000000100
# 5  : 1110110000010000
# 6  : 0000000000010001
# 7  : 1110001100001000
# 8  : 0000000000000000
# 9  : 1110110000010000
# 10 : 0000000000010010
# 11 : 1110001100001000
# 12 : 0000000000010000
# 13 : 1111110000010000
# 14 : 0000000000011000
# 15 : 1110001100000010
# 16 : 0000000000010000
# 17 : 1111110010001000
# 18 : 0000000000010001
# 19 : 1111110000010000
# 20 : 0000000000010010
# 21 : 1111000010001000
# 22 : 0000000000001100
# 23 : 1110101010000111
# ==============================
# Machine step 0
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0]
# instr 0: @3, assembly_lineno: 3
# Machine step 1
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0]
# instr 1: D=A;null, assembly_lineno: 4
# Machine step 2
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0]
# instr 2: @16, assembly_lineno: 5
# Machine step 3
# D: 3, A: 16, M[16:20]: [0, 0, 0, 0]
# instr 3: M=D;null, assembly_lineno: 6
# Machine step 4
# D: 3, A: 16, M[16:20]: [3, 0, 0, 0]
# instr 4: @4, assembly_lineno: 8
# Machine step 5
# D: 3, A: 4, M[16:20]: [3, 0, 0, 0]
# instr 5: D=A;null, assembly_lineno: 9
# Machine step 6
# D: 4, A: 4, M[16:20]: [3, 0, 0, 0]
# instr 6: @17, assembly_lineno: 10
# Machine step 7
# D: 4, A: 17, M[16:20]: [3, 0, 0, 0]
# instr 7: M=D;null, assembly_lineno: 11
# Machine step 8
# D: 4, A: 17, M[16:20]: [3, 4, 0, 0]
# instr 8: @0, assembly_lineno: 13
# Machine step 9
# D: 4, A: 0, M[16:20]: [3, 4, 0, 0]
# instr 9: D=A;null, assembly_lineno: 14
# Machine step 10
# D: 0, A: 0, M[16:20]: [3, 4, 0, 0]
# instr 10: @18, assembly_lineno: 15
# Machine step 11
# D: 0, A: 18, M[16:20]: [3, 4, 0, 0]
# instr 11: M=D;null, assembly_lineno: 16
# Machine step 12
# D: 0, A: 18, M[16:20]: [3, 4, 0, 0]
# instr 12: @16, assembly_lineno: 19
# Machine step 13
# D: 0, A: 16, M[16:20]: [3, 4, 0, 0]
# instr 13: D=M;null, assembly_lineno: 20
# Machine step 14
# D: 3, A: 16, M[16:20]: [3, 4, 0, 0]
# instr 14: @24, assembly_lineno: 21
# Machine step 15
# D: 3, A: 24, M[16:20]: [3, 4, 0, 0]
# instr 15: null=D;JEQ, assembly_lineno: 22
# Machine step 16
# D: 3, A: 24, M[16:20]: [3, 4, 0, 0]
# instr 16: @16, assembly_lineno: 24
# Machine step 17
# D: 3, A: 16, M[16:20]: [3, 4, 0, 0]
# instr 17: M=M-1;null, assembly_lineno: 25
# Machine step 18
# D: 3, A: 16, M[16:20]: [2, 4, 0, 0]
# instr 18: @17, assembly_lineno: 27
# Machine step 19
# D: 3, A: 17, M[16:20]: [2, 4, 0, 0]
# instr 19: D=M;null, assembly_lineno: 28
# Machine step 20
# D: 4, A: 17, M[16:20]: [2, 4, 0, 0]
# instr 20: @18, assembly_lineno: 29
# Machine step 21
# D: 4, A: 18, M[16:20]: [2, 4, 0, 0]
# instr 21: M=D+M;null, assembly_lineno: 30
# Machine step 22
# D: 4, A: 18, M[16:20]: [2, 4, 4, 0]
# instr 22: @12, assembly_lineno: 31
# Machine step 23
# D: 4, A: 12, M[16:20]: [2, 4, 4, 0]
# instr 23: null=0;JMP, assembly_lineno: 32
# Machine step 24
# D: 4, A: 12, M[16:20]: [2, 4, 4, 0]
# instr 12: @16, assembly_lineno: 19
# Machine step 25
# D: 4, A: 16, M[16:20]: [2, 4, 4, 0]
# instr 13: D=M;null, assembly_lineno: 20
# Machine step 26
# D: 2, A: 16, M[16:20]: [2, 4, 4, 0]
# instr 14: @24, assembly_lineno: 21
# Machine step 27
# D: 2, A: 24, M[16:20]: [2, 4, 4, 0]
# instr 15: null=D;JEQ, assembly_lineno: 22
# Machine step 28
# D: 2, A: 24, M[16:20]: [2, 4, 4, 0]
# instr 16: @16, assembly_lineno: 24
# Machine step 29
# D: 2, A: 16, M[16:20]: [2, 4, 4, 0]
# instr 17: M=M-1;null, assembly_lineno: 25
# Machine step 30
# D: 2, A: 16, M[16:20]: [1, 4, 4, 0]
# instr 18: @17, assembly_lineno: 27
# Machine step 31
# D: 2, A: 17, M[16:20]: [1, 4, 4, 0]
# instr 19: D=M;null, assembly_lineno: 28
# Machine step 32
# D: 4, A: 17, M[16:20]: [1, 4, 4, 0]
# instr 20: @18, assembly_lineno: 29
# Machine step 33
# D: 4, A: 18, M[16:20]: [1, 4, 4, 0]
# instr 21: M=D+M;null, assembly_lineno: 30
# Machine step 34
# D: 4, A: 18, M[16:20]: [1, 4, 8, 0]
# instr 22: @12, assembly_lineno: 31
# Machine step 35
# D: 4, A: 12, M[16:20]: [1, 4, 8, 0]
# instr 23: null=0;JMP, assembly_lineno: 32
# Machine step 36
# D: 4, A: 12, M[16:20]: [1, 4, 8, 0]
# instr 12: @16, assembly_lineno: 19
# Machine step 37
# D: 4, A: 16, M[16:20]: [1, 4, 8, 0]
# instr 13: D=M;null, assembly_lineno: 20
# Machine step 38
# D: 1, A: 16, M[16:20]: [1, 4, 8, 0]
# instr 14: @24, assembly_lineno: 21
# Machine step 39
# D: 1, A: 24, M[16:20]: [1, 4, 8, 0]
# instr 15: null=D;JEQ, assembly_lineno: 22
# Machine step 40
# D: 1, A: 24, M[16:20]: [1, 4, 8, 0]
# instr 16: @16, assembly_lineno: 24
# Machine step 41
# D: 1, A: 16, M[16:20]: [1, 4, 8, 0]
# instr 17: M=M-1;null, assembly_lineno: 25
# Machine step 42
# D: 1, A: 16, M[16:20]: [0, 4, 8, 0]
# instr 18: @17, assembly_lineno: 27
# Machine step 43
# D: 1, A: 17, M[16:20]: [0, 4, 8, 0]
# instr 19: D=M;null, assembly_lineno: 28
# Machine step 44
# D: 4, A: 17, M[16:20]: [0, 4, 8, 0]
# instr 20: @18, assembly_lineno: 29
# Machine step 45
# D: 4, A: 18, M[16:20]: [0, 4, 8, 0]
# instr 21: M=D+M;null, assembly_lineno: 30
# Machine step 46
# D: 4, A: 18, M[16:20]: [0, 4, 12, 0]
# instr 22: @12, assembly_lineno: 31
# Machine step 47
# D: 4, A: 12, M[16:20]: [0, 4, 12, 0]
# instr 23: null=0;JMP, assembly_lineno: 32
# Machine step 48
# D: 4, A: 12, M[16:20]: [0, 4, 12, 0]
# instr 12: @16, assembly_lineno: 19
# Machine step 49
# D: 4, A: 16, M[16:20]: [0, 4, 12, 0]
# instr 13: D=M;null, assembly_lineno: 20
# Machine step 50
# D: 0, A: 16, M[16:20]: [0, 4, 12, 0]
# instr 14: @24, assembly_lineno: 21
# Machine step 51
# D: 0, A: 24, M[16:20]: [0, 4, 12, 0]
# instr 15: null=D;JEQ, assembly_lineno: 22
# Machine step 52
# Finished execution

# %%
print('Symbol table after execution')
# print('='*30)
# print(machine)
print('='*30)
print(ass)
