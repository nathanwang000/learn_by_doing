# %% [markdown]
# # VM translator based on elements of computing systems
#
# ## The computed results should be at the top of the stack

# %%
import sys, os
from io import StringIO
from typing import List, Dict, Tuple
from enum import Enum
from functools import partial

# sys.path.append(os.path.join(os.path.dirname(__file__), "..", "lib"))
from lib.utils import pretty_format_dict, binary_or, binary_and, binary_add, binary_flip, binary_neg, WORD_SIZE
from lib.utils import bin2dec, print_with_lines, dec2bin, WORD_SIZE
from lib.assembler import Assembler, Machine

CommandType = Enum(
    'CommandType', 
    ['C_ARITHMETIC', # page 130, fig 7.5: e.g., add, sub, neg ...
     'C_PUSH', # page 131: push <segment> index, e.g., push argument 0 // stack.push(argument[0])
     'C_POP', # page 131: pop <segment> index, e.g., pop argment 0 // argment[0] = stack.pop()
     'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
     'C_GOTO',  # page 159: goto label, unconditional jump
     'C_IF', # page 159: if-goto label, pc = label if stack.pop() != 0 else pc + 1, label must be within the same function
     'C_FUNCTION', # page 163: function f k, where k is num local variables
     'C_RETURN', # page 163: return, return control to the caller
     'C_CALL', # page 163: call f n, where f is a function and n is number of arguments
    ]
)

ARITHMETIC_COMMANDS = ['add', 'sub', 'neg', 'eq', 'gt', 'lt', 'and', 'or', 'not']

def getCommandType(command: str)->CommandType:
    if command in ARITHMETIC_COMMANDS:
        return CommandType.C_ARITHMETIC
    elif command.startswith('push'):
        return CommandType.C_PUSH
    elif command.startswith('pop'):
        return CommandType.C_POP
    elif command.startswith('label'):
        return CommandType.C_LABEL
    elif command.startswith('goto'):
        return CommandType.C_GOTO
    elif command.startswith('if-goto'):
        return CommandType.C_IF
    elif command.startswith('function'):
        return CommandType.C_FUNCTION
    elif command.startswith('return'):
        return CommandType.C_RETURN
    elif command.startswith('call'):
        return CommandType.C_CALL
    
class Interpretor: 
    # AKA python machine that runs VM code
    '''VM interpretor, essentially a simulator in python
    instead of compiling the code, just run on the fly instead
    this is like the class Machine in assembler

    Here we assume VM only contain functions

    Interpreter is essentially a python machine
    where the hardware (including ROM) is specified by self.machine
    and machine language is python (the generated code is the concatenation
    of all the text in code execution parts of self.advance)
    '''
    def __init__(self, 
                 multi_line_comment_open:str='/*',
                 multi_line_comment_close:str='*/',
                 heap_size:int=5, temp_size:int=5, 
                 max_steps:int=100, verbose:bool=True):
        self.multi_line_comment_open = multi_line_comment_open
        self.multi_line_comment_close = multi_line_comment_close
        self.temp_size = temp_size
        self.heap_size = heap_size
        self.max_steps = max_steps
        self.verbose = verbose
        
    def load(self, vm_fnames: List[str]):
        self.machine = {
            'functions': {"Sys.psuedo_init": ["call Sys.init 0"]},
            'current_function': "Sys.psuedo_init",
            'pc': 0, # line number within current_function
            'stack': [], # page 141 M[256:2048]
            'heap': [0] * self.heap_size, # for storing objects, page 141 M[2048:16383]
            # 'sp': 0 # stack pointer: next top location in stack, page 142 R0, this need to be separately implemneted for hack machine but not for python
            'segments': {
                'argument': 0, # dynamically allocated per function, point to a cell on stack, page 142 R2
                'local': 0, # dynamically allocated per function, point to a cell on stack, page 142 R1
                'static': {}, # shared by all functions in the same .vm file, page 141 M[16:256]
                # 'constant': [], # psshared by all functions
                # 'this': [], # pointer to heap: pointer[0]
                # 'that': [], # pointer to heap: pointer[1]
                'pointer': [0, 0], # pointer to this and that, page 142 M[3:5]
                'temp': [0] * self.temp_size, # shared by all functions, page 142 M[5:13]
            }
        }

        # set up symbol lookup: symbol['current_function']['label'] -> 'pc'
        # b/c label in VM is attached to the function scope
        self.symbol_table = {}
        
        # populate functions and symbol table
        for fname in vm_fnames:
            with open(fname) as f:
                self._first_pass(f.readlines())

        if self.verbose:
            print('functions parsed')
            print(pretty_format_dict(self.machine['functions']))
            print('symbol table')
            print(pretty_format_dict(self.symbol_table))

        # make sure Sys.init is encountered
        assert self.machine['current_function'] in self.machine['functions'], f'{self.machine["current_function"]} need to be in vm code'

    def __repr__(self):
        return f'VM interpretor(Machine=\n{pretty_format_dict(self.machine)}\nSymbolTable=\n{pretty_format_dict(self.symbol_table)}\n)'

    def _first_pass(self, codes: List[str], in_comment:bool=False):
        # parse out all the functions into self.machine['functions'], add labels and function to symbol table,
        # and strip out comments
        # in_comment: are you in multi line comment /* */?
        func_name, func_codes = None, []
        lineno_within_func = 0

        for i, l in enumerate(codes):

            if in_comment:
                if self.multi_line_comment_close in l:
                    # comment closed
                    len_c_close = len(self.multi_line_comment_close)
                    l = l[l.index(self.multi_line_comment_close)+len_c_close:]
                    in_comment = False
                else:
                    # comment continue to open, ignore the line
                    continue
                    
            # sanitize line
            l = l.strip()
            orig_l = l
            if '//' in l: # comment
                l = l[:l.index('//')].strip()
            if self.multi_line_comment_open in l:
                in_comment = not orig_l.endswith(self.multi_line_comment_close)
                l = l[:l.index(self.multi_line_comment_open)].strip()
                
            # scrape function
            ct = getCommandType(l)
            if ct is CommandType.C_FUNCTION:
                if func_name is not None:
                    self.machine['functions'][func_name] = func_codes
                    return self._first_pass(codes[i:])
                else:
                    func_name = l.split()[1]
                    if l != "": 
                        lineno_within_func += 1
                        func_codes.append(l)
            elif ct is CommandType.C_LABEL:
                # 'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
                assert func_name is not None, f'label {l} need to be within a function'
                label = l.split()[1]
                if func_name not in self.symbol_table:
                    self.symbol_table[func_name] = {}
                self.symbol_table[func_name][label] = lineno_within_func
            else:
                if l != "": 
                    lineno_within_func += 1
                    func_codes.append(l)
                
        if func_name is not None:
            self.machine['functions'][func_name] = func_codes
            return


    def advance(self)->bool:
        func_name, pc = self.machine['current_function'], self.machine['pc']
        codes = self.machine['functions'][func_name]

        if self.verbose:
            print('stack:', self.machine['stack'])
            print(f"argument: {self.machine['segments']['argument']}, local: {self.machine['segments']['local']}, len(stack): {len(self.machine['stack'])}")

        
        if pc >= len(codes):
            # finished execution
            return False

        code = codes[pc]
        ct = getCommandType(code)
        if self.verbose:
            print(f'instruction {func_name}[{pc}]: {code}, type: {ct}')
        
        self.machine['pc'] += 1
        # instruction decoding and then execute
        stack = self.machine['stack']
        heap = self.machine['heap']
        segments = self.machine['segments']
        
        if ct is CommandType.C_ARITHMETIC:
            # 'C_ARITHMETIC', # page 130, fig 7.5: e.g., add, sub, neg ...
            x = self.machine['stack'].pop()
            if code in ['add', 'sub', 'eq', 'gt', 'lt', 'and', 'or']:
                # binary operators, TODO: rewrite some of them to bitwise operations 
                y = self.machine['stack'].pop()
                ret = {
                    'add': partial(binary_add, word_size=WORD_SIZE),
                    'sub': lambda a, b: a - b,
                    'eq': lambda a, b: a == b,
                    'gt': lambda a, b: a > b,
                    'lt': lambda a, b: a < b,
                    'and': partial(binary_and, word_size=WORD_SIZE),
                    'or': partial(binary_or, word_size=WORD_SIZE),
                }[code](y, x) # y, x b/c y is first pushed
            else: 
                # unary operators
                ret = {
                    'neg': partial(binary_neg, word_size=WORD_SIZE),
                    'not': partial(binary_flip, word_size=WORD_SIZE),
                }[code](x)
                    
            self.machine['stack'].append(ret)
        elif ct is CommandType.C_PUSH:
            # 'C_PUSH', # page 131: push <segment> index, e.g., push argument 0 // stack.push(argument[0])
            _, segment, index = code.split()
            index = int(index)
            
            if segment == 'argument':
                # dynamically allocated per function, point to a cell on stack
                val = stack[segments[segment] + index]
            elif segment == 'local':
                # dynamically allocated per function, point to a cell on stack
                val = stack[segments[segment] + index]
            elif segment == 'static':
                # shared by all functions in the same .vm file, page 141 M[16:256]
                val = segments[segment][self.machine['current_function']][index]
            elif segment == 'constant':
                # shared by all functions
                val = index
            elif segment == 'this':
                # pointer to heap: pointer[0]
                val = heap[segment['pointer'][0] + index]
            elif segment == 'that':
                # pointer to heap: pointer[1]
                val = heap[segment['pointer'][1] + index]
            elif segment == 'pointer':
                # pointer to this and that, page 142 M[3:5]
                val = self.machine[segment][index]
            elif segment == 'temp':
                # shared by all functions, page 142 M[5:13]
                val = self.machine[segment][index]
            else:
                assert False, f'unknown segment {segment}'
                
            self.machine['stack'].append(val)
            
        elif ct is CommandType.C_POP:
            # 'C_POP', # page 131: pop <segment> index, e.g., pop argment 0 // argment[0] = stack.pop()
            _, segment, index = code.split()
            index = int(index)

            val = self.machine['stack'].pop()
            if segment == 'argument':
                # dynamically allocated per function, point to a cell on stack
                stack[segments[segment] + index] = val
            elif segment == 'local':
                # dynamically allocated per function, point to a cell on stack
                stack[segments[segment] + index] = val
            elif segment == 'static':
                # shared by all functions in .vm file, page 141 M[16:256]
                static_seg = segments[segment]
                curr_f = self.machine['current_function']
                if curr_f not in static_seg:
                    static_seg[curr_f] = [0] * (index+1)
                segments[segment][index] = val
            elif segment == 'constant':
                # shared by all functions
                assert False, 'cannot pop to constant'
            elif segment == 'this':
                # pointer to heap: pointer[0]
                heap[segment['pointer'][0] + index] = val
            elif segment == 'that':
                # pointer to heap: pointer[1]
                heap[segment['pointer'][1] + index] = val
            elif segment == 'pointer':
                # pointer to this and that, page 142 M[3:5]
                self.machine[segment][index] = val
            elif segment == 'temp':
                # shared by all functions, page 142 M[5:13]
                self.machine[segment][index] = val
            else:
                assert False, f'unknown segment {segment}'

        elif ct is CommandType.C_LABEL:
            # 'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
            assert False, f'{ct} command should only be encountered in _first_pass, as in this second pass it should have been resolved'
        elif ct is CommandType.C_GOTO:
            # 'C_GOTO',  # page 159: goto label, unconditional jump
            label = code.split()[1]
            assert label in self.symbol_table[self.machine['current_function']], f'{label} not in current function scope'
            self.machine['pc'] = self.symbol_table[self.machine['current_function']][label]
        elif ct is CommandType.C_IF: 
            # 'C_IF', # page 159: if-goto label, pc = label if stack.pop() != 0 else pc + 1, label must be within the same function
            label = code.split()[1]
            label_pc = self.symbol_table[self.machine['current_function']][label]
            if self.machine['stack'].pop() != 0:
                self.machine['pc'] = label_pc # no need to consider = 0 case b/c that's already default
        elif ct is CommandType.C_FUNCTION:
            # 'C_FUNCTION', # page 163: function f k, where k is num local variables
            n_local = int(code.split()[2])
            for _ in range(n_local):
                stack.append(0)
        elif ct is CommandType.C_RETURN:
            # 'C_RETURN', # page 163: return, return control to the caller
            frame = segments['local']
            prev_f, prev_f_lineno = stack[frame-5] # ret_addr for python machine it should be (), but for hack it will be a label to ROM
            # put return value back at the new top: see page 162, here I think the assumption is a function always returns something, could be None
            stack[segments['argument']] = stack.pop()
            # print(frame, len(stack))
            sp = segments['argument'] + 1
            segments['pointer'] = [stack[frame-2], stack[frame-1]]
            segments['argument'] = stack[frame-3]
            segments['local'] = stack[frame-4]
            self.machine['stack'] = self.machine['stack'][:sp]

            # goto prev function
            self.machine['current_function'] = prev_f
            self.machine['pc'] = prev_f_lineno
        elif ct is CommandType.C_CALL:
            # 'C_CALL', # page 163: call f n, where f is a function and n is number of arguments
            _, next_f, n_args = code.split()
            n_args = int(n_args)
            # push return-address
            curr_f, pc = self.machine['current_function'], self.machine['pc']
            stack.append((curr_f, pc))
            # push lcl
            stack.append(segments['local'])
            # pushl arg
            stack.append(segments['argument'])
            # push this and that
            stack.extend(segments['pointer'])
            # arg = SP - n - 5
            segments['argument'] = len(stack) - n_args - 5
            # lcl = SP
            segments['local']= len(stack)
            # goto f
            self.machine['current_function'] = next_f
            self.machine['pc'] = 0
        else:
            assert False, f'command {ct} not found'
        
        return True

    
    def __call__(self, vm_fnames: List[str]):
        self.load(vm_fnames)

        steps = 0
        while steps <= self.max_steps:
            if self.verbose:
                print('Machine step', steps)
            steps += 1
            ok = self.advance()
            if not ok:
                print('Finished execution')
                return
        print(f'Program terminated b/c exceeding max step of {self.max_steps}')        

vm_interpretor = Interpretor()
vm_interpretor(['vm_codes/recursion.vm'])
# print(vm_interpretor)
# Out:
# functions parsed
# {
#     "Sys.psuedo_init": [
#         "call Sys.init 0"
#     ],
#     "multNat": [
#         "function multNat 0",
#         "push argument 0",
#         "push constant 0",
#         "gt",
#         "if-goto recurse",
#         "push constant 0",
#         "return",
#         "push argument 0",
#         "push constant -1",
#         "add",
#         "push argument 1",
#         "call multNat 2",
#         "push argument 1",
#         "add",
#         "return"
#     ],
#     "Sys.init": [
#         "function Sys.init 0",
#         "push constant 3",
#         "push constant 4",
#         "call multNat 2",
#         "return"
#     ]
# }
# symbol table
# {
#     "multNat": {
#         "recurse": 7
#     }
# }
# Machine step 0
# stack: []
# argument: 0, local: 0, len(stack): 0
# instruction Sys.psuedo_init[0]: call Sys.init 0, type: CommandType.C_CALL
# Machine step 1
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0]
# argument: 0, local: 5, len(stack): 5
# instruction Sys.init[0]: function Sys.init 0, type: CommandType.C_FUNCTION
# Machine step 2
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0]
# argument: 0, local: 5, len(stack): 5
# instruction Sys.init[1]: push constant 3, type: CommandType.C_PUSH
# Machine step 3
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3]
# argument: 0, local: 5, len(stack): 6
# instruction Sys.init[2]: push constant 4, type: CommandType.C_PUSH
# Machine step 4
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4]
# argument: 0, local: 5, len(stack): 7
# instruction Sys.init[3]: call multNat 2, type: CommandType.C_CALL
# Machine step 5
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0]
# argument: 5, local: 12, len(stack): 12
# instruction multNat[0]: function multNat 0, type: CommandType.C_FUNCTION
# Machine step 6
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0]
# argument: 5, local: 12, len(stack): 12
# instruction multNat[1]: push argument 0, type: CommandType.C_PUSH
# Machine step 7
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 3]
# argument: 5, local: 12, len(stack): 13
# instruction multNat[2]: push constant 0, type: CommandType.C_PUSH
# Machine step 8
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 3, 0]
# argument: 5, local: 12, len(stack): 14
# instruction multNat[3]: gt, type: CommandType.C_ARITHMETIC
# Machine step 9
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, True]
# argument: 5, local: 12, len(stack): 13
# instruction multNat[4]: if-goto recurse, type: CommandType.C_IF
# Machine step 10
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0]
# argument: 5, local: 12, len(stack): 12
# instruction multNat[7]: push argument 0, type: CommandType.C_PUSH
# Machine step 11
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 3]
# argument: 5, local: 12, len(stack): 13
# instruction multNat[8]: push constant -1, type: CommandType.C_PUSH
# Machine step 12
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 3, -1]
# argument: 5, local: 12, len(stack): 14
# instruction multNat[9]: add, type: CommandType.C_ARITHMETIC
# Machine step 13
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2]
# argument: 5, local: 12, len(stack): 13
# instruction multNat[10]: push argument 1, type: CommandType.C_PUSH
# Machine step 14
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4]
# argument: 5, local: 12, len(stack): 14
# instruction multNat[11]: call multNat 2, type: CommandType.C_CALL
# Machine step 15
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0]
# argument: 12, local: 19, len(stack): 19
# instruction multNat[0]: function multNat 0, type: CommandType.C_FUNCTION
# Machine step 16
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0]
# argument: 12, local: 19, len(stack): 19
# instruction multNat[1]: push argument 0, type: CommandType.C_PUSH
# Machine step 17
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 2]
# argument: 12, local: 19, len(stack): 20
# instruction multNat[2]: push constant 0, type: CommandType.C_PUSH
# Machine step 18
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 2, 0]
# argument: 12, local: 19, len(stack): 21
# instruction multNat[3]: gt, type: CommandType.C_ARITHMETIC
# Machine step 19
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, True]
# argument: 12, local: 19, len(stack): 20
# instruction multNat[4]: if-goto recurse, type: CommandType.C_IF
# Machine step 20
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0]
# argument: 12, local: 19, len(stack): 19
# instruction multNat[7]: push argument 0, type: CommandType.C_PUSH
# Machine step 21
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 2]
# argument: 12, local: 19, len(stack): 20
# instruction multNat[8]: push constant -1, type: CommandType.C_PUSH
# Machine step 22
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 2, -1]
# argument: 12, local: 19, len(stack): 21
# instruction multNat[9]: add, type: CommandType.C_ARITHMETIC
# Machine step 23
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1]
# argument: 12, local: 19, len(stack): 20
# instruction multNat[10]: push argument 1, type: CommandType.C_PUSH
# Machine step 24
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4]
# argument: 12, local: 19, len(stack): 21
# instruction multNat[11]: call multNat 2, type: CommandType.C_CALL
# Machine step 25
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0]
# argument: 19, local: 26, len(stack): 26
# instruction multNat[0]: function multNat 0, type: CommandType.C_FUNCTION
# Machine step 26
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0]
# argument: 19, local: 26, len(stack): 26
# instruction multNat[1]: push argument 0, type: CommandType.C_PUSH
# Machine step 27
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 1]
# argument: 19, local: 26, len(stack): 27
# instruction multNat[2]: push constant 0, type: CommandType.C_PUSH
# Machine step 28
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 1, 0]
# argument: 19, local: 26, len(stack): 28
# instruction multNat[3]: gt, type: CommandType.C_ARITHMETIC
# Machine step 29
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, True]
# argument: 19, local: 26, len(stack): 27
# instruction multNat[4]: if-goto recurse, type: CommandType.C_IF
# Machine step 30
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0]
# argument: 19, local: 26, len(stack): 26
# instruction multNat[7]: push argument 0, type: CommandType.C_PUSH
# Machine step 31
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 1]
# argument: 19, local: 26, len(stack): 27
# instruction multNat[8]: push constant -1, type: CommandType.C_PUSH
# Machine step 32
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 1, -1]
# argument: 19, local: 26, len(stack): 28
# instruction multNat[9]: add, type: CommandType.C_ARITHMETIC
# Machine step 33
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0]
# argument: 19, local: 26, len(stack): 27
# instruction multNat[10]: push argument 1, type: CommandType.C_PUSH
# Machine step 34
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4]
# argument: 19, local: 26, len(stack): 28
# instruction multNat[11]: call multNat 2, type: CommandType.C_CALL
# Machine step 35
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0]
# argument: 26, local: 33, len(stack): 33
# instruction multNat[0]: function multNat 0, type: CommandType.C_FUNCTION
# Machine step 36
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0]
# argument: 26, local: 33, len(stack): 33
# instruction multNat[1]: push argument 0, type: CommandType.C_PUSH
# Machine step 37
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0, 0]
# argument: 26, local: 33, len(stack): 34
# instruction multNat[2]: push constant 0, type: CommandType.C_PUSH
# Machine step 38
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0, 0, 0]
# argument: 26, local: 33, len(stack): 35
# instruction multNat[3]: gt, type: CommandType.C_ARITHMETIC
# Machine step 39
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0, False]
# argument: 26, local: 33, len(stack): 34
# instruction multNat[4]: if-goto recurse, type: CommandType.C_IF
# Machine step 40
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0]
# argument: 26, local: 33, len(stack): 33
# instruction multNat[5]: push constant 0, type: CommandType.C_PUSH
# Machine step 41
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4, ('multNat', 12), 26, 19, 0, 0, 0]
# argument: 26, local: 33, len(stack): 34
# instruction multNat[6]: return, type: CommandType.C_RETURN
# Machine step 42
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0]
# argument: 19, local: 26, len(stack): 27
# instruction multNat[12]: push argument 1, type: CommandType.C_PUSH
# Machine step 43
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 0, 4]
# argument: 19, local: 26, len(stack): 28
# instruction multNat[13]: add, type: CommandType.C_ARITHMETIC
# Machine step 44
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 1, 4, ('multNat', 12), 19, 12, 0, 0, 4]
# argument: 19, local: 26, len(stack): 27
# instruction multNat[14]: return, type: CommandType.C_RETURN
# Machine step 45
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 4]
# argument: 12, local: 19, len(stack): 20
# instruction multNat[12]: push argument 1, type: CommandType.C_PUSH
# Machine step 46
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 4, 4]
# argument: 12, local: 19, len(stack): 21
# instruction multNat[13]: add, type: CommandType.C_ARITHMETIC
# Machine step 47
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 2, 4, ('multNat', 12), 12, 5, 0, 0, 8]
# argument: 12, local: 19, len(stack): 20
# instruction multNat[14]: return, type: CommandType.C_RETURN
# Machine step 48
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 8]
# argument: 5, local: 12, len(stack): 13
# instruction multNat[12]: push argument 1, type: CommandType.C_PUSH
# Machine step 49
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 8, 4]
# argument: 5, local: 12, len(stack): 14
# instruction multNat[13]: add, type: CommandType.C_ARITHMETIC
# Machine step 50
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 3, 4, ('Sys.init', 4), 5, 0, 0, 0, 12]
# argument: 5, local: 12, len(stack): 13
# instruction multNat[14]: return, type: CommandType.C_RETURN
# Machine step 51
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 12]
# argument: 0, local: 5, len(stack): 6
# instruction Sys.init[4]: return, type: CommandType.C_RETURN
# Machine step 52
# stack: [12]
# argument: 0, local: 0, len(stack): 1
# Finished execution

# %%
LanguageType = Enum(
    'LanguageType', 
    ['VM', 'ASSEMBLY']
)

def lineStrip(code:str)->List[str]:
    return list(filter(lambda x: x != "",
                       map(lambda x: x.strip(), code.split('\n'))))
    
class Translator:
    '''VM code -> Assembly code'''
    def __init__(self, 
                 multi_line_comment_open:str='/*',
                 multi_line_comment_close:str='*/',
                 temp_addr:int=5,
                 verbose:bool=True):
        self.multi_line_comment_open = multi_line_comment_open
        self.multi_line_comment_close = multi_line_comment_close
        self.n_symbol = 0 # used to track number of system symbol assigned
        self.current_function = None # useful for label: func_name$label
        self.temp_addr = temp_addr
        self.verbose = verbose

    def getVMcode(self, fname:str, lineno:int):
        '''return the vm code corresponds to fname and lineno; this handles pseudo code as well'''
        return self.compiledCodes[self.compiledLinenos.index((fname, lineno))][0]
        
    def load(self, vm_fnames: List[str]):
        self.pc = 0 # where we are in the code
        self.sanitizedCodes = {} # fname -> {"codes", "linenos"}

        for fname in vm_fnames:
            with open(fname) as f:
                codes, linenos = self._sanitizeCodes(f.readlines())
                self.sanitizedCodes[fname] = {"codes": codes, "linenos": linenos}

        # insert initialization code, call Sys.init with no args
        # this is intermingled with direct assembly code for setting up 
        # utilities like symbols for setting up == operator
        self.compiledCodes = [
            # setup SP value to 256
            ('@256', LanguageType.ASSEMBLY),
            ('D=A', LanguageType.ASSEMBLY),
            ('@SP', LanguageType.ASSEMBLY),
            ('M=D', LanguageType.ASSEMBLY),
            # call initialization
            ("call Sys.init 0", LanguageType.VM),
            # jump to the end
            ("@0END", LanguageType.ASSEMBLY),
            ("0;JMP", LanguageType.ASSEMBLY),
        ]
        self.compiledLinenos = [("psuedo code file", i) for i in range(len(self.compiledCodes))]
        psuedo_lines = len(self.compiledCodes)

        # add back middle code
        for k, v in self.sanitizedCodes.items():
            self.compiledCodes.extend(
                zip(v["codes"], [LanguageType.VM] * len(v["codes"]))
            )
            for ln in v["linenos"]:
                self.compiledLinenos.append((k, ln))

        # jump to end of the code
        end_codes = [
            # start with number to differentiate from user label
            ("(0END)", LanguageType.ASSEMBLY),
        ]
        self.compiledCodes.extend(end_codes)
        self.compiledLinenos.extend([("psuedo code file", psuedo_lines+i) for i in range(len(end_codes))])

        if self.verbose:
            print('code sanitized')
            print('==============')
            print(pretty_format_dict(self.sanitizedCodes))
            print('compiled code')
            print('==============')
            print(self)
            print('==============')

    def __repr__(self):
        ret = ['VM translator(']
        for (code, langType), (fn, ln) in zip(self.compiledCodes, self.compiledLinenos):
            ret.append(f'({fn}, {ln}, {langType}): {code}')
        return "\n".join(ret + [')'])

    def _sanitizeCodes(self, codes: List[str])->Tuple[List[str], List[int]]:
        '''
        strip out comments e.g. // or /* comment */
        return (a list of command that are sanitized without comments, linenos in orignal code)
        '''
        def helper(codes:List[str], lineno:int, in_comment:bool, result: Tuple[List[str], List[int]])->Tuple[List[str], List[int]]:
            if len(codes) == 0:
                return result
            l, rest = codes[0], codes[1:]

            if in_comment:
                if self.multi_line_comment_close in l:
                    # comment closed
                    len_c_close = len(self.multi_line_comment_close)
                    l = l[l.index(self.multi_line_comment_close)+len_c_close:]
                    in_comment = False
                else:
                    # comment continue to open, ignore the line
                    return helper(rest, lineno+1, True, result)

            # sanitize line
            l = l.strip()
            orig_l = l
            if '//' in l: # comment
                l = l[:l.index('//')].strip()
            if self.multi_line_comment_open in l:
                in_comment = not orig_l.endswith(self.multi_line_comment_close)
                l = l[:l.index(self.multi_line_comment_open)].strip()

            if l == "":
                return helper(rest, lineno+1, in_comment, result)

            sanitized_codes, linenos = result
            return helper(rest, lineno+1, in_comment, (sanitized_codes + [l], linenos + [lineno]))
                        
        return helper(codes, 0, False, ([], []))

    def assignSystemSymbol(self)->int:
        self.n_symbol += 1
        return self.n_symbol - 1

    def _assPushD(self)->List[str]:
        '''push D to stack'''
        return lineStrip(
            '''
            @SP
            A=M
            M=D // M[M[SP]] is the tip of stack
            // M[SP] += 1
            @SP
            M=M+1
            '''
        )
        
    def _assPushA(self, s:str)->List[str]:
        '''push A=@s to stack in assembly code'''
        
        return [
            f'@{s}',
            'D=A',
        ] + self._assPushD()

    def _assPopToD(self)->List[str]:
        'pop stack to D'
        return lineStrip(
            '''
            // D=stack.pop()
            @SP
            A=M-1
            D=M // D=M[M[SP]-1] that is stack.top()
            @SP
            M=M-1 // M[SP] -= 1 // D=stack.pop()
            '''
        )
        
    def _assArithmetic(self, code:str)->List[str]:
        "given vm command output assembly codes"
        # 'C_ARITHMETIC', # page 130, fig 7.5: e.g., add, sub, neg ...
        # temp[1] = self.machine['stack'].pop()
        ass_codes = []
        temp = self.temp_addr
        ass_codes.extend(
            self._assPopToD() + lineStrip(
                f'''
                // M[temp+1]=D
                @{temp+1}
                M=D
                '''
            )
        )

        assert code in ARITHMETIC_COMMANDS, 'code invalid'
        if code in ['add', 'sub', 'eq', 'gt', 'lt', 'and', 'or']:
            # binary operators
            # temp[0] = self.machine['stack'].pop(), use temp[0] to store the first pushed element b/c stack is FILO
            ass_codes.extend(
                self._assPopToD() + lineStrip(
                    f'''
                    // M[temp+0]=D
                    @{temp+0}
                    M=D
                    '''
                )
            )

            # comput and push to stack
            if code == 'add':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        //* stack.push(temp[0] + temp[1])
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D+M
                        '''
                    ) + self._assPushD())
                
            elif code == 'sub':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        //* stack.push(temp[0] - temp[1])
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        '''
                    ) + self._assPushD())
            elif code == 'eq': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // temp[0]-temp[1] == 0
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        // test if eq 0
                        @{self.assignSystemSymbol()}ADD_TRUE
                        D;JEQ
                        // case for not true: push 0 and continue
                        '''
                    ) + self._assPushA('0') + lineStrip(
                        f'''
                        @{self.assignSystemSymbol()}cont
                        0;JMP
                        // case for true: push 0xF to top
                        ({self.n_symbol-2}ADD_TRUE)  
                        '''
                    ) + self._assPushA(bin2dec('1'*WORD_SIZE)) + lineStrip(
                        f'''
                        // continue
                        ({self.n_symbol-1}cont)
                        '''
                    ))
            elif code == 'gt': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // temp[0]-temp[1] > 0
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        // test if > 0
                        @{self.assignSystemSymbol()}ADD_TRUE
                        D;JGT
                        // case for not true: push 0 and continue
                        '''
                    ) + self._assPushA('0') + lineStrip(
                        f'''
                        @{self.assignSystemSymbol()}cont
                        0;JMP
                        // case for true: push 0xF to top
                        ({self.n_symbol-2}ADD_TRUE)  
                        '''
                    ) + self._assPushA(bin2dec('1'*WORD_SIZE)) + lineStrip(
                        f'''
                        // continue
                        ({self.n_symbol-1}cont)
                        '''
                    ))
            elif code == 'lt': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // temp[0]-temp[1] < 0
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        // test if < 0
                        @{self.assignSystemSymbol()}ADD_TRUE
                        D;JLT
                        // case for not true: push 0 and continue
                        '''
                    ) + self._assPushA('0') + lineStrip(
                        f'''
                        @{self.assignSystemSymbol()}cont
                        0;JMP
                        // case for true: push 0xF to top
                        ({self.n_symbol-2}ADD_TRUE)  
                        '''
                    ) + self._assPushA(bin2dec('1'*WORD_SIZE)) + lineStrip(
                        f'''
                        // continue
                        ({self.n_symbol-1}cont)
                        '''
                    ))
            elif code == 'and': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // M[temp + 0] & M[temp + 1] and push to stack
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D&M
                        '''
                    ) + self._assPushD()
                )
            elif code == 'or': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // M[temp + 0] | M[temp + 1] and push to stack
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D|M
                        '''
                    ) + self._assPushD()
                )
        else: 
            # unary operators
            if code == 'neg':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // -M[temp + 1]
                        @{temp+1}
                        D=-M
                        '''
                    ) + self._assPushD()
                )
            elif code == 'not':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // !M[temp + 1]
                        @{temp+1}
                        D=!M
                        '''
                    ) + self._assPushD()
                )
        return ass_codes

    def _assFunc(self, code:str)->List[str]:
        "given vm command output assembly codes"
        # 'C_FUNCTION', # page 163: function f k, where k is num local variables
        n_local = int(code.split()[2])
        func_name = code.split()[1]
        ass_codes = [f'({func_name})']
        for _ in range(n_local):
            ass_codes.extend(self._assPushA('0'))
        return ass_codes

    def _assCall(self, command:str)->List[str]:
        "given vm command output assembly codes"
        # # 'C_CALL', # page 163: call f n, where f is a function and n is number of arguments
        ass_codes = []
        _, next_f, n_args = command.split()
        n_args = int(n_args)
        # push return-address
        ass_codes.extend(self._assPushA(f'{self.assignSystemSymbol()}return-address'))
        # push M[lcl]
        ass_codes.extend(
            lineStrip(
                '''
                @LCL
                D=M
                '''
            ) + self._assPushD())
        # pushl M[arg]
        ass_codes.extend(
            lineStrip(
                '''
                @ARG
                D=M
                '''
            ) + self._assPushD())
        # push M[this] and M[that]
        ass_codes.extend(
            lineStrip(
                '''
                @THIS
                D=M
                '''
            ) + self._assPushD())
        ass_codes.extend(
            lineStrip(
                '''
                @THAT
                D=M
                '''
            ) + self._assPushD())
        # arg = SP - n_args - 5; 5 b/c we just pushed 5 elements
        ass_codes.extend([
            '@SP',
            'D=M',
            f'@{n_args}',
            'D=D-A',
            '@5',
            'D=D-A',
            '@ARG',
            'M=D',
        ])
        # lcl = SP; set local to the new function's local segment
        ass_codes.extend([
            '@SP',
            'D=M',
            '@LCL',
            'M=D',
        ])
        # goto f
        ass_codes.extend([
            f'@{next_f}',
            '0;JMP',
        ])
        ass_codes.append(f'({self.n_symbol-1}return-address)')
        return ass_codes

    def _assPop(self, code:str, fname:str)->List[str]:
        # 'C_POP', # page 131: pop <segment> index, e.g., pop argment 0 // argment[0] = stack.pop()
        _, segment, index = code.split()
        index = int(index)
        ret = self._assPopToD()
        
        if segment == 'argument':
            # dynamically allocated per function, point to a cell on stack
            ret += lineStrip(
                f'''
                // M[M[ARG]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @ARG
                D=D+M // M[ARG]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[ARG]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'local':
            # dynamically allocated per function, point to a cell on stack
            ret += lineStrip(
                f'''
                // M[M[LCL]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @LCL
                D=D+M // M[LCL]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[LCL]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'static':
            # shared by all functions in .vm file, page 141 M[16:256]            
            ret += lineStrip(
                f'''
                // M[fname.index] = stack.pop()
                @{fname}.{index}
                M=D
                '''
            )
        elif segment == 'constant':
            # shared by all functions
            assert False, 'cannot pop to constant'
        elif segment == 'this':
            ret += lineStrip(
                f'''
                // M[M[THIS]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @THIS
                D=D+M // M[THIS]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[THIS]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'that':
            ret += lineStrip(
                f'''
                // M[M[THAT]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @THAT
                D=D+M // M[THAT]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[LCL]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'pointer':
            # pointer[0] and pointer[1] are this and that, page 142 M[3:5]
            ret += lineStrip(
                f'''
                // M[THIS+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @THIS
                D=D+A // THIS +index
                @{self.temp_addr+1}
                M=D // temp[1] = THIS +index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'temp':
            # shared by all functions, page 142 M[5:13]
            ret += lineStrip(
                f'''
                // M[temp+index] = stack.pop()
                @{self.temp_addr+index}
                M=D
                '''
            )
        else:
            assert False, f'unknown segment {segment}'

        return ret

    def _assPush(self, code:str, fname:str)->List[str]:
        "given vm code output assembly codes; fname is the file where the command is from"
        # 'C_PUSH', # page 131: push <segment> index, e.g., push argument 0 // stack.push(argument[0])
        _, segment, index = code.split()
        index = int(index)

        # load value into D
        if segment == 'argument':
            # dynamically allocated per function, point to a cell on stack
            # D = M[M[ARG] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @ARG
                    A=D+M
                    // A is M[ARG] + index
                    D=M
                    '''
            )
        elif segment == 'local':
            # dynamically allocated per function, point to a cell on stack
            # D = M[M[LCL] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @LCL
                    A=D+M
                    // A is M[LCL] + index
                    D=M
                    '''
            )
        elif segment == 'static':
            # shared by all functions in XXX.vm file, page 141 M[16:256]
            # D = M[XXX.{index}]
            ret = lineStrip(
                    f'''
                    @{fname}.{index}
                    D=M
                    '''
            )
        elif segment == 'constant':
            # shared by all functions
            # D = index
            ret = [f'@{index}', 'D=A']
        elif segment == 'this':
            # pointer to heap: THIS
            # D = M[M[THIS] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @THIS
                    A=D+M
                    // A is M[THIS] + index
                    D=M
                    '''
            )
        elif segment == 'that':
            # pointer to heap: THAT
            # D = M[M[THAT] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @THAT
                    A=D+M
                    // A is M[THAT] + index
                    D=M
                    '''
            )
        elif segment == 'pointer':
            # pointer to this and that, page 142 M[3:5]
            # D = M[THIS+index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @THIS
                    A=D+A
                    D=M
                    '''
            )
        elif segment == 'temp':
            # shared by all functions, page 142 M[5:13]
            # D = M[R5+index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @{self.temp_addr}
                    A=D+A
                    D=M
                    '''
            )
        else:
            assert False, f'unknown segment {segment}'
            
        return ret + self._assPushD()

    def _assReturn(self)->List[str]:
        # 'C_RETURN', # page 163: return, return control to the caller
        # stack looks like [arguments, prev_ret_addr, prev_local, prev_arg, prev_this, prev_that, lcl]
        # the new SP will be ARG+1 b/c ARG is where new returned value is
        return lineStrip(
            f'''
            // M[temp+0] = M[LCL]
            @LCL
            D=M
            @{self.temp_addr+0}
            MD=D
            // M[temp+1] = M[M[temp+0]-5] ; save return addr
            @5
            A=D-A // M[temp+0]-5
            D=M // M[M[temp+0]-5]
            @{self.temp_addr+1}
            M=D
            '''
        ) + self._assPopToD() + lineStrip(
            f'''
            // M[M[ARG]] = stack.pop(); pop the return value to arg segment
            @ARG
            A=M 
            M=D // M[M[ARG]] = poped value
            // M[SP] = M[ARG] + 1
            @ARG
            D=M+1
            @SP
            M=D
            // M[THAT] = M[M[TEMP+0]-1]
            @{self.temp_addr+0}
            A=M-1
            D=M
            @THAT
            M=D
            // M[THIS] = M[M[TEMP+0]-2]
            @2
            D=A
            @{self.temp_addr+0}
            A=M-D
            D=M
            @THIS
            M=D
            // M[ARG] = M[M[TEMP+0]-3]
            @3
            D=A
            @{self.temp_addr+0}
            A=M-D
            D=M
            @ARG
            M=D
            // M[LCL] = M[M[TEMP+0]-4]
            @4
            D=A
            @{self.temp_addr+0}
            A=M-D
            D=M
            @LCL
            M=D
            // goto M[temp+1]
            @{self.temp_addr+1}
            A=M
            0;JMP
            '''
        )

    def _assIf(self, code:str, func_name:str)->List[str]:
        # 'C_IF', # page 159: if-goto label, pc = label if stack.pop() != 0 else pc + 1, label must be within the same function
        label = code.split()[1]
        return self._assPopToD() + lineStrip(
            f'''
            @{func_name}${label}
            D;JNE
            '''
        )
        
    def _assGoto(self, code:str, func_name:str)->List[str]:
        # 'C_GOTO',  # page 159: goto label, unconditional jump
        label = code.split()[1]
        return lineStrip(
            f'''
            @{func_name}${label}
            0;JMP
            '''
        )

    def _assLabel(self, code:str, func_name:str)->List[str]:
        # 'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
        label = code.split()[1]
        return lineStrip(
            f'''
            ({func_name}${label})
            '''
        )
        
    def advance(self)->Tuple[bool, List[str], Tuple[str, int]]:
        '''
        return (ok, assembly codes for the next command, reference_line_in_orig_file)

        references in book:
        'pc': 0, # line number within current_function
        'stack': [], # page 141 M[256:2048]
        'heap': [0]*self.heap_size, # for storing objects, page 141 M[2048:16383]
        'sp': 0 # stack pointer: next top location in stack, page 142 R0
        'segments': {
            'argument': 0, # dynamically allocated per function, point to a cell on stack, page 142 R2
            'local': 0, # dynamically allocated per function, point to a cell on stack, page 142 R1
            'static': [0] * self.static_size, # shared by all functions in .vm file, page 141 M[16:256]
            'constant': [], # psshared by all functions
            'this': [], # pointer to heap: pointer[0]
            'that': [], # pointer to heap: pointer[1]
            'pointer': [0, 0], # pointer to this and that, page 142 M[3:5]
            'temp': [0] * self.temp_size, # shared by all functions, page 142 M[5:13]
        '''

        if self.pc >= len(self.compiledCodes):
            # finished execution
            return False, [""], ("", 0)

        # instruction fetching
        code, langType = self.compiledCodes[self.pc]
        fname, code_lineno = self.compiledLinenos[self.pc]
        ct = getCommandType(code)
        self.pc += 1        
        if self.verbose:
            print(f'instruction from {fname}[{code_lineno}]: {code}, type: {ct}')

        if langType == LanguageType.ASSEMBLY:
            return True, [code], (fname, code_lineno)

        # instruction decoding and then execute
        ass_codes = []
        if ct is CommandType.C_ARITHMETIC:
            # page 130: add, neg, ...
            ass_codes.extend(self._assArithmetic(code))
        elif ct is CommandType.C_PUSH:
            # page 131: push <segment:e.g., local> <index: e.g., 1>
            ass_codes.extend(self._assPush(code, fname))
        elif ct is CommandType.C_POP:
            # page 131: pop <segment> index
            ass_codes.extend(self._assPop(code, fname))
        elif ct is CommandType.C_LABEL:
            # page 159: label symbol
            ass_codes.extend(self._assLabel(code, self.current_function))
        elif ct is CommandType.C_GOTO:
            # page 159: goto label
            ass_codes.extend(self._assGoto(code, self.current_function))
        elif ct is CommandType.C_IF:
            # if-goto label
            ass_codes.extend(self._assIf(code, self.current_function))
        elif ct is CommandType.C_FUNCTION:
            # page 163: function f k
            self.current_function = code.split()[1]
            ass_codes.extend(self._assFunc(code))
        elif ct is CommandType.C_RETURN:
            # page 163: return
            ass_codes.extend(self._assReturn())
        elif ct is CommandType.C_CALL:
            # page 163: call f n
            ass_codes.extend(self._assCall(code))
        else:
            assert False, f'command {ct} not founc'

        return True, ass_codes, (fname, code_lineno)
    
    def __call__(self, vm_fnames: List[str])->Tuple[str, List[Tuple[str, int]]]:
        '''
        given vm code in vm_fnames, 
        return (assembly_code, vm_code_lines that corresponds to assembly_code for debug)
        '''
        self.load(vm_fnames)

        codes = []
        linenos = []
        while True:
            ok, ass_codes, lineno = self.advance()
            if not ok: break
            codes.append(ass_codes)
            linenos.append(lineno)

        # build assembly line to vm line dictionary
        tgtRef2srcRef = []
        for (fname, i), codeLines in zip(linenos, codes):
            tgtRef2srcRef.extend([(fname, i)] * len(codeLines))
            
        return '\n'.join(['\n'.join(codeLines) for codeLines in codes]), tgtRef2srcRef

# %%
vm_translator = Translator()
# generated_code, assLine2vmLine = vm_translator(['vm_codes/add_const.vm']) # stack[-1]: 2 + 3 = 5
# generated_code, assLine2vmLine = vm_translator(['vm_codes/double.vm']) # stack[-1]: 3 * 2 = 6
generated_code, assLine2vmLine = vm_translator(['vm_codes/recursion.vm']) # stack[-1]: 3 * 4 = 12
print('=========')
print_with_lines(generated_code)
# Out:
# code sanitized
# ==============
# {
#     "vm_codes/recursion.vm": {
#         "codes": [
#             "function multNat 0",
#             "push argument 0",
#             "push constant 0",
#             "gt",
#             "if-goto recurse",
#             "push constant 0",
#             "return",
#             "label recurse",
#             "push argument 0",
#             "push constant -1",
#             "add",
#             "push argument 1",
#             "call multNat 2",
#             "push argument 1",
#             "add",
#             "return",
#             "function Sys.init 0",
#             "push constant 3",
#             "push constant 4",
#             "call multNat 2",
#             "return"
#         ],
#         "linenos": [
#             0,
#             3,
#             4,
#             6,
#             7,
#             8,
#             9,
#             10,
#             12,
#             13,
#             14,
#             15,
#             16,
#             17,
#             18,
#             19,
#             21,
#             26,
#             27,
#             28,
#             29
#         ]
#     }
# }
# compiled code
# ==============
# VM translator(
# (psuedo code file, 0, LanguageType.ASSEMBLY): @256
# (psuedo code file, 1, LanguageType.ASSEMBLY): D=A
# (psuedo code file, 2, LanguageType.ASSEMBLY): @SP
# (psuedo code file, 3, LanguageType.ASSEMBLY): M=D
# (psuedo code file, 4, LanguageType.VM): call Sys.init 0
# (psuedo code file, 5, LanguageType.ASSEMBLY): @0END
# (psuedo code file, 6, LanguageType.ASSEMBLY): 0;JMP
# (vm_codes/recursion.vm, 0, LanguageType.VM): function multNat 0
# (vm_codes/recursion.vm, 3, LanguageType.VM): push argument 0
# (vm_codes/recursion.vm, 4, LanguageType.VM): push constant 0
# (vm_codes/recursion.vm, 6, LanguageType.VM): gt
# (vm_codes/recursion.vm, 7, LanguageType.VM): if-goto recurse
# (vm_codes/recursion.vm, 8, LanguageType.VM): push constant 0
# (vm_codes/recursion.vm, 9, LanguageType.VM): return
# (vm_codes/recursion.vm, 10, LanguageType.VM): label recurse
# (vm_codes/recursion.vm, 12, LanguageType.VM): push argument 0
# (vm_codes/recursion.vm, 13, LanguageType.VM): push constant -1
# (vm_codes/recursion.vm, 14, LanguageType.VM): add
# (vm_codes/recursion.vm, 15, LanguageType.VM): push argument 1
# (vm_codes/recursion.vm, 16, LanguageType.VM): call multNat 2
# (vm_codes/recursion.vm, 17, LanguageType.VM): push argument 1
# (vm_codes/recursion.vm, 18, LanguageType.VM): add
# (vm_codes/recursion.vm, 19, LanguageType.VM): return
# (vm_codes/recursion.vm, 21, LanguageType.VM): function Sys.init 0
# (vm_codes/recursion.vm, 26, LanguageType.VM): push constant 3
# (vm_codes/recursion.vm, 27, LanguageType.VM): push constant 4
# (vm_codes/recursion.vm, 28, LanguageType.VM): call multNat 2
# (vm_codes/recursion.vm, 29, LanguageType.VM): return
# (psuedo code file, 7, LanguageType.ASSEMBLY): (0END)
# )
# ==============
# instruction from psuedo code file[0]: @256, type: None
# instruction from psuedo code file[1]: D=A, type: None
# instruction from psuedo code file[2]: @SP, type: None
# instruction from psuedo code file[3]: M=D, type: None
# instruction from psuedo code file[4]: call Sys.init 0, type: CommandType.C_CALL
# instruction from psuedo code file[5]: @0END, type: None
# instruction from psuedo code file[6]: 0;JMP, type: None
# instruction from vm_codes/recursion.vm[0]: function multNat 0, type: CommandType.C_FUNCTION
# instruction from vm_codes/recursion.vm[3]: push argument 0, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[4]: push constant 0, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[6]: gt, type: CommandType.C_ARITHMETIC
# instruction from vm_codes/recursion.vm[7]: if-goto recurse, type: CommandType.C_IF
# instruction from vm_codes/recursion.vm[8]: push constant 0, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[9]: return, type: CommandType.C_RETURN
# instruction from vm_codes/recursion.vm[10]: label recurse, type: CommandType.C_LABEL
# instruction from vm_codes/recursion.vm[12]: push argument 0, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[13]: push constant -1, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[14]: add, type: CommandType.C_ARITHMETIC
# instruction from vm_codes/recursion.vm[15]: push argument 1, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[16]: call multNat 2, type: CommandType.C_CALL
# instruction from vm_codes/recursion.vm[17]: push argument 1, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[18]: add, type: CommandType.C_ARITHMETIC
# instruction from vm_codes/recursion.vm[19]: return, type: CommandType.C_RETURN
# instruction from vm_codes/recursion.vm[21]: function Sys.init 0, type: CommandType.C_FUNCTION
# instruction from vm_codes/recursion.vm[26]: push constant 3, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[27]: push constant 4, type: CommandType.C_PUSH
# instruction from vm_codes/recursion.vm[28]: call multNat 2, type: CommandType.C_CALL
# instruction from vm_codes/recursion.vm[29]: return, type: CommandType.C_RETURN
# instruction from psuedo code file[7]: (0END), type: None
# =========
# 0   : @256
# 1   : D=A
# 2   : @SP
# 3   : M=D
# 4   : @0return-address
# 5   : D=A
# 6   : @SP
# 7   : A=M
# 8   : M=D // M[M[SP]] is the tip of stack
# 9   : // M[SP] += 1
# 10  : @SP
# 11  : M=M+1
# 12  : @LCL
# 13  : D=M
# 14  : @SP
# 15  : A=M
# 16  : M=D // M[M[SP]] is the tip of stack
# 17  : // M[SP] += 1
# 18  : @SP
# 19  : M=M+1
# 20  : @ARG
# 21  : D=M
# 22  : @SP
# 23  : A=M
# 24  : M=D // M[M[SP]] is the tip of stack
# 25  : // M[SP] += 1
# 26  : @SP
# 27  : M=M+1
# 28  : @THIS
# 29  : D=M
# 30  : @SP
# 31  : A=M
# 32  : M=D // M[M[SP]] is the tip of stack
# 33  : // M[SP] += 1
# 34  : @SP
# 35  : M=M+1
# 36  : @THAT
# 37  : D=M
# 38  : @SP
# 39  : A=M
# 40  : M=D // M[M[SP]] is the tip of stack
# 41  : // M[SP] += 1
# 42  : @SP
# 43  : M=M+1
# 44  : @SP
# 45  : D=M
# 46  : @0
# 47  : D=D-A
# 48  : @5
# 49  : D=D-A
# 50  : @ARG
# 51  : M=D
# 52  : @SP
# 53  : D=M
# 54  : @LCL
# 55  : M=D
# 56  : @Sys.init
# 57  : 0;JMP
# 58  : (0return-address)
# 59  : @0END
# 60  : 0;JMP
# 61  : (multNat)
# 62  : @0
# 63  : D=A
# 64  : @ARG
# 65  : A=D+M
# 66  : // A is M[ARG] + index
# 67  : D=M
# 68  : @SP
# 69  : A=M
# 70  : M=D // M[M[SP]] is the tip of stack
# 71  : // M[SP] += 1
# 72  : @SP
# 73  : M=M+1
# 74  : @0
# 75  : D=A
# 76  : @SP
# 77  : A=M
# 78  : M=D // M[M[SP]] is the tip of stack
# 79  : // M[SP] += 1
# 80  : @SP
# 81  : M=M+1
# 82  : // D=stack.pop()
# 83  : @SP
# 84  : A=M-1
# 85  : D=M // D=M[M[SP]-1] that is stack.top()
# 86  : @SP
# 87  : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 88  : // M[temp+1]=D
# 89  : @6
# 90  : M=D
# 91  : // D=stack.pop()
# 92  : @SP
# 93  : A=M-1
# 94  : D=M // D=M[M[SP]-1] that is stack.top()
# 95  : @SP
# 96  : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 97  : // M[temp+0]=D
# 98  : @5
# 99  : M=D
# 100 : // temp[0]-temp[1] > 0
# 101 : @5
# 102 : D=M
# 103 : @6
# 104 : D=D-M
# 105 : // test if > 0
# 106 : @1ADD_TRUE
# 107 : D;JGT
# 108 : // case for not true: push 0 and continue
# 109 : @0
# 110 : D=A
# 111 : @SP
# 112 : A=M
# 113 : M=D // M[M[SP]] is the tip of stack
# 114 : // M[SP] += 1
# 115 : @SP
# 116 : M=M+1
# 117 : @2cont
# 118 : 0;JMP
# 119 : // case for true: push 0xF to top
# 120 : (1ADD_TRUE)
# 121 : @-1
# 122 : D=A
# 123 : @SP
# 124 : A=M
# 125 : M=D // M[M[SP]] is the tip of stack
# 126 : // M[SP] += 1
# 127 : @SP
# 128 : M=M+1
# 129 : // continue
# 130 : (2cont)
# 131 : // D=stack.pop()
# 132 : @SP
# 133 : A=M-1
# 134 : D=M // D=M[M[SP]-1] that is stack.top()
# 135 : @SP
# 136 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 137 : @multNat$recurse
# 138 : D;JNE
# 139 : @0
# 140 : D=A
# 141 : @SP
# 142 : A=M
# 143 : M=D // M[M[SP]] is the tip of stack
# 144 : // M[SP] += 1
# 145 : @SP
# 146 : M=M+1
# 147 : // M[temp+0] = M[LCL]
# 148 : @LCL
# 149 : D=M
# 150 : @5
# 151 : MD=D
# 152 : // M[temp+1] = M[M[temp+0]-5] ; save return addr
# 153 : @5
# 154 : A=D-A // M[temp+0]-5
# 155 : D=M // M[M[temp+0]-5]
# 156 : @6
# 157 : M=D
# 158 : // D=stack.pop()
# 159 : @SP
# 160 : A=M-1
# 161 : D=M // D=M[M[SP]-1] that is stack.top()
# 162 : @SP
# 163 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 164 : // M[M[ARG]] = stack.pop(); pop the return value to arg segment
# 165 : @ARG
# 166 : A=M
# 167 : M=D // M[M[ARG]] = poped value
# 168 : // M[SP] = M[ARG] + 1
# 169 : @ARG
# 170 : D=M+1
# 171 : @SP
# 172 : M=D
# 173 : // M[THAT] = M[M[TEMP+0]-1]
# 174 : @5
# 175 : A=M-1
# 176 : D=M
# 177 : @THAT
# 178 : M=D
# 179 : // M[THIS] = M[M[TEMP+0]-2]
# 180 : @2
# 181 : D=A
# 182 : @5
# 183 : A=M-D
# 184 : D=M
# 185 : @THIS
# 186 : M=D
# 187 : // M[ARG] = M[M[TEMP+0]-3]
# 188 : @3
# 189 : D=A
# 190 : @5
# 191 : A=M-D
# 192 : D=M
# 193 : @ARG
# 194 : M=D
# 195 : // M[LCL] = M[M[TEMP+0]-4]
# 196 : @4
# 197 : D=A
# 198 : @5
# 199 : A=M-D
# 200 : D=M
# 201 : @LCL
# 202 : M=D
# 203 : // goto M[temp+1]
# 204 : @6
# 205 : A=M
# 206 : 0;JMP
# 207 : (multNat$recurse)
# 208 : @0
# 209 : D=A
# 210 : @ARG
# 211 : A=D+M
# 212 : // A is M[ARG] + index
# 213 : D=M
# 214 : @SP
# 215 : A=M
# 216 : M=D // M[M[SP]] is the tip of stack
# 217 : // M[SP] += 1
# 218 : @SP
# 219 : M=M+1
# 220 : @-1
# 221 : D=A
# 222 : @SP
# 223 : A=M
# 224 : M=D // M[M[SP]] is the tip of stack
# 225 : // M[SP] += 1
# 226 : @SP
# 227 : M=M+1
# 228 : // D=stack.pop()
# 229 : @SP
# 230 : A=M-1
# 231 : D=M // D=M[M[SP]-1] that is stack.top()
# 232 : @SP
# 233 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 234 : // M[temp+1]=D
# 235 : @6
# 236 : M=D
# 237 : // D=stack.pop()
# 238 : @SP
# 239 : A=M-1
# 240 : D=M // D=M[M[SP]-1] that is stack.top()
# 241 : @SP
# 242 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 243 : // M[temp+0]=D
# 244 : @5
# 245 : M=D
# 246 : //* stack.push(temp[0] + temp[1])
# 247 : @5
# 248 : D=M
# 249 : @6
# 250 : D=D+M
# 251 : @SP
# 252 : A=M
# 253 : M=D // M[M[SP]] is the tip of stack
# 254 : // M[SP] += 1
# 255 : @SP
# 256 : M=M+1
# 257 : @1
# 258 : D=A
# 259 : @ARG
# 260 : A=D+M
# 261 : // A is M[ARG] + index
# 262 : D=M
# 263 : @SP
# 264 : A=M
# 265 : M=D // M[M[SP]] is the tip of stack
# 266 : // M[SP] += 1
# 267 : @SP
# 268 : M=M+1
# 269 : @3return-address
# 270 : D=A
# 271 : @SP
# 272 : A=M
# 273 : M=D // M[M[SP]] is the tip of stack
# 274 : // M[SP] += 1
# 275 : @SP
# 276 : M=M+1
# 277 : @LCL
# 278 : D=M
# 279 : @SP
# 280 : A=M
# 281 : M=D // M[M[SP]] is the tip of stack
# 282 : // M[SP] += 1
# 283 : @SP
# 284 : M=M+1
# 285 : @ARG
# 286 : D=M
# 287 : @SP
# 288 : A=M
# 289 : M=D // M[M[SP]] is the tip of stack
# 290 : // M[SP] += 1
# 291 : @SP
# 292 : M=M+1
# 293 : @THIS
# 294 : D=M
# 295 : @SP
# 296 : A=M
# 297 : M=D // M[M[SP]] is the tip of stack
# 298 : // M[SP] += 1
# 299 : @SP
# 300 : M=M+1
# 301 : @THAT
# 302 : D=M
# 303 : @SP
# 304 : A=M
# 305 : M=D // M[M[SP]] is the tip of stack
# 306 : // M[SP] += 1
# 307 : @SP
# 308 : M=M+1
# 309 : @SP
# 310 : D=M
# 311 : @2
# 312 : D=D-A
# 313 : @5
# 314 : D=D-A
# 315 : @ARG
# 316 : M=D
# 317 : @SP
# 318 : D=M
# 319 : @LCL
# 320 : M=D
# 321 : @multNat
# 322 : 0;JMP
# 323 : (3return-address)
# 324 : @1
# 325 : D=A
# 326 : @ARG
# 327 : A=D+M
# 328 : // A is M[ARG] + index
# 329 : D=M
# 330 : @SP
# 331 : A=M
# 332 : M=D // M[M[SP]] is the tip of stack
# 333 : // M[SP] += 1
# 334 : @SP
# 335 : M=M+1
# 336 : // D=stack.pop()
# 337 : @SP
# 338 : A=M-1
# 339 : D=M // D=M[M[SP]-1] that is stack.top()
# 340 : @SP
# 341 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 342 : // M[temp+1]=D
# 343 : @6
# 344 : M=D
# 345 : // D=stack.pop()
# 346 : @SP
# 347 : A=M-1
# 348 : D=M // D=M[M[SP]-1] that is stack.top()
# 349 : @SP
# 350 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 351 : // M[temp+0]=D
# 352 : @5
# 353 : M=D
# 354 : //* stack.push(temp[0] + temp[1])
# 355 : @5
# 356 : D=M
# 357 : @6
# 358 : D=D+M
# 359 : @SP
# 360 : A=M
# 361 : M=D // M[M[SP]] is the tip of stack
# 362 : // M[SP] += 1
# 363 : @SP
# 364 : M=M+1
# 365 : // M[temp+0] = M[LCL]
# 366 : @LCL
# 367 : D=M
# 368 : @5
# 369 : MD=D
# 370 : // M[temp+1] = M[M[temp+0]-5] ; save return addr
# 371 : @5
# 372 : A=D-A // M[temp+0]-5
# 373 : D=M // M[M[temp+0]-5]
# 374 : @6
# 375 : M=D
# 376 : // D=stack.pop()
# 377 : @SP
# 378 : A=M-1
# 379 : D=M // D=M[M[SP]-1] that is stack.top()
# 380 : @SP
# 381 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 382 : // M[M[ARG]] = stack.pop(); pop the return value to arg segment
# 383 : @ARG
# 384 : A=M
# 385 : M=D // M[M[ARG]] = poped value
# 386 : // M[SP] = M[ARG] + 1
# 387 : @ARG
# 388 : D=M+1
# 389 : @SP
# 390 : M=D
# 391 : // M[THAT] = M[M[TEMP+0]-1]
# 392 : @5
# 393 : A=M-1
# 394 : D=M
# 395 : @THAT
# 396 : M=D
# 397 : // M[THIS] = M[M[TEMP+0]-2]
# 398 : @2
# 399 : D=A
# 400 : @5
# 401 : A=M-D
# 402 : D=M
# 403 : @THIS
# 404 : M=D
# 405 : // M[ARG] = M[M[TEMP+0]-3]
# 406 : @3
# 407 : D=A
# 408 : @5
# 409 : A=M-D
# 410 : D=M
# 411 : @ARG
# 412 : M=D
# 413 : // M[LCL] = M[M[TEMP+0]-4]
# 414 : @4
# 415 : D=A
# 416 : @5
# 417 : A=M-D
# 418 : D=M
# 419 : @LCL
# 420 : M=D
# 421 : // goto M[temp+1]
# 422 : @6
# 423 : A=M
# 424 : 0;JMP
# 425 : (Sys.init)
# 426 : @3
# 427 : D=A
# 428 : @SP
# 429 : A=M
# 430 : M=D // M[M[SP]] is the tip of stack
# 431 : // M[SP] += 1
# 432 : @SP
# 433 : M=M+1
# 434 : @4
# 435 : D=A
# 436 : @SP
# 437 : A=M
# 438 : M=D // M[M[SP]] is the tip of stack
# 439 : // M[SP] += 1
# 440 : @SP
# 441 : M=M+1
# 442 : @4return-address
# 443 : D=A
# 444 : @SP
# 445 : A=M
# 446 : M=D // M[M[SP]] is the tip of stack
# 447 : // M[SP] += 1
# 448 : @SP
# 449 : M=M+1
# 450 : @LCL
# 451 : D=M
# 452 : @SP
# 453 : A=M
# 454 : M=D // M[M[SP]] is the tip of stack
# 455 : // M[SP] += 1
# 456 : @SP
# 457 : M=M+1
# 458 : @ARG
# 459 : D=M
# 460 : @SP
# 461 : A=M
# 462 : M=D // M[M[SP]] is the tip of stack
# 463 : // M[SP] += 1
# 464 : @SP
# 465 : M=M+1
# 466 : @THIS
# 467 : D=M
# 468 : @SP
# 469 : A=M
# 470 : M=D // M[M[SP]] is the tip of stack
# 471 : // M[SP] += 1
# 472 : @SP
# 473 : M=M+1
# 474 : @THAT
# 475 : D=M
# 476 : @SP
# 477 : A=M
# 478 : M=D // M[M[SP]] is the tip of stack
# 479 : // M[SP] += 1
# 480 : @SP
# 481 : M=M+1
# 482 : @SP
# 483 : D=M
# 484 : @2
# 485 : D=D-A
# 486 : @5
# 487 : D=D-A
# 488 : @ARG
# 489 : M=D
# 490 : @SP
# 491 : D=M
# 492 : @LCL
# 493 : M=D
# 494 : @multNat
# 495 : 0;JMP
# 496 : (4return-address)
# 497 : // M[temp+0] = M[LCL]
# 498 : @LCL
# 499 : D=M
# 500 : @5
# 501 : MD=D
# 502 : // M[temp+1] = M[M[temp+0]-5] ; save return addr
# 503 : @5
# 504 : A=D-A // M[temp+0]-5
# 505 : D=M // M[M[temp+0]-5]
# 506 : @6
# 507 : M=D
# 508 : // D=stack.pop()
# 509 : @SP
# 510 : A=M-1
# 511 : D=M // D=M[M[SP]-1] that is stack.top()
# 512 : @SP
# 513 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 514 : // M[M[ARG]] = stack.pop(); pop the return value to arg segment
# 515 : @ARG
# 516 : A=M
# 517 : M=D // M[M[ARG]] = poped value
# 518 : // M[SP] = M[ARG] + 1
# 519 : @ARG
# 520 : D=M+1
# 521 : @SP
# 522 : M=D
# 523 : // M[THAT] = M[M[TEMP+0]-1]
# 524 : @5
# 525 : A=M-1
# 526 : D=M
# 527 : @THAT
# 528 : M=D
# 529 : // M[THIS] = M[M[TEMP+0]-2]
# 530 : @2
# 531 : D=A
# 532 : @5
# 533 : A=M-D
# 534 : D=M
# 535 : @THIS
# 536 : M=D
# 537 : // M[ARG] = M[M[TEMP+0]-3]
# 538 : @3
# 539 : D=A
# 540 : @5
# 541 : A=M-D
# 542 : D=M
# 543 : @ARG
# 544 : M=D
# 545 : // M[LCL] = M[M[TEMP+0]-4]
# 546 : @4
# 547 : D=A
# 548 : @5
# 549 : A=M-D
# 550 : D=M
# 551 : @LCL
# 552 : M=D
# 553 : // goto M[temp+1]
# 554 : @6
# 555 : A=M
# 556 : 0;JMP
# 557 : (0END)

# %%
### translate assembly to machine code
ass = Assembler()
machine_codes, ass_linenos = ass(generated_code)

print('Machine code')
print('='*30)
print_with_lines(machine_codes)
print('='*30)

### execute machine code
machine = Machine(verbose=True, memory_size=1000, max_steps=1000)
machine(machine_codes, 
        # show vm code reference and the vm codeline as well as assebly code line
        [((fn, i), vm_translator.getVMcode(fn, i), generated_code.split('\n')[j])for (fn, i), j in zip(
            [assLine2vmLine[k] for k in ass_linenos], # select out codes without comment
            ass_linenos)]
       )

print('Symbol table after execution')
print('='*30)
print(ass)
# Out:
# Machine code
# ==============================
# 0   : 0000000100000000
# 1   : 1110110000010000
# 2   : 0000000000000000
# 3   : 1110001100001000
# 4   : 0000000000110101
# 5   : 1110110000010000
# 6   : 0000000000000000
# 7   : 1111110000100000
# 8   : 1110001100001000
# 9   : 0000000000000000
# 10  : 1111110111001000
# 11  : 0000000000000001
# 12  : 1111110000010000
# 13  : 0000000000000000
# 14  : 1111110000100000
# 15  : 1110001100001000
# 16  : 0000000000000000
# 17  : 1111110111001000
# 18  : 0000000000000010
# 19  : 1111110000010000
# 20  : 0000000000000000
# 21  : 1111110000100000
# 22  : 1110001100001000
# 23  : 0000000000000000
# 24  : 1111110111001000
# 25  : 0000000000000011
# 26  : 1111110000010000
# 27  : 0000000000000000
# 28  : 1111110000100000
# 29  : 1110001100001000
# 30  : 0000000000000000
# 31  : 1111110111001000
# 32  : 0000000000000100
# 33  : 1111110000010000
# 34  : 0000000000000000
# 35  : 1111110000100000
# 36  : 1110001100001000
# 37  : 0000000000000000
# 38  : 1111110111001000
# 39  : 0000000000000000
# 40  : 1111110000010000
# 41  : 0000000000000000
# 42  : 1110010011010000
# 43  : 0000000000000101
# 44  : 1110010011010000
# 45  : 0000000000000010
# 46  : 1110001100001000
# 47  : 0000000000000000
# 48  : 1111110000010000
# 49  : 0000000000000001
# 50  : 1110001100001000
# 51  : 0000000101100010
# 52  : 1110101010000111
# 53  : 0000000111010011
# 54  : 1110101010000111
# 55  : 0000000000000000
# 56  : 1110110000010000
# 57  : 0000000000000010
# 58  : 1111000010100000
# 59  : 1111110000010000
# 60  : 0000000000000000
# 61  : 1111110000100000
# 62  : 1110001100001000
# 63  : 0000000000000000
# 64  : 1111110111001000
# 65  : 0000000000000000
# 66  : 1110110000010000
# 67  : 0000000000000000
# 68  : 1111110000100000
# 69  : 1110001100001000
# 70  : 0000000000000000
# 71  : 1111110111001000
# 72  : 0000000000000000
# 73  : 1111110010100000
# 74  : 1111110000010000
# 75  : 0000000000000000
# 76  : 1111110010001000
# 77  : 0000000000000110
# 78  : 1110001100001000
# 79  : 0000000000000000
# 80  : 1111110010100000
# 81  : 1111110000010000
# 82  : 0000000000000000
# 83  : 1111110010001000
# 84  : 0000000000000101
# 85  : 1110001100001000
# 86  : 0000000000000101
# 87  : 1111110000010000
# 88  : 0000000000000110
# 89  : 1111010011010000
# 90  : 0000000001100101
# 91  : 1110001100000001
# 92  : 0000000000000000
# 93  : 1110110000010000
# 94  : 0000000000000000
# 95  : 1111110000100000
# 96  : 1110001100001000
# 97  : 0000000000000000
# 98  : 1111110111001000
# 99  : 0000000001101100
# 100 : 1110101010000111
# 101 : 0111111111111111
# 102 : 1110110000010000
# 103 : 0000000000000000
# 104 : 1111110000100000
# 105 : 1110001100001000
# 106 : 0000000000000000
# 107 : 1111110111001000
# 108 : 0000000000000000
# 109 : 1111110010100000
# 110 : 1111110000010000
# 111 : 0000000000000000
# 112 : 1111110010001000
# 113 : 0000000010101100
# 114 : 1110001100000101
# 115 : 0000000000000000
# 116 : 1110110000010000
# 117 : 0000000000000000
# 118 : 1111110000100000
# 119 : 1110001100001000
# 120 : 0000000000000000
# 121 : 1111110111001000
# 122 : 0000000000000001
# 123 : 1111110000010000
# 124 : 0000000000000101
# 125 : 1110001100011000
# 126 : 0000000000000101
# 127 : 1110010011100000
# 128 : 1111110000010000
# 129 : 0000000000000110
# 130 : 1110001100001000
# 131 : 0000000000000000
# 132 : 1111110010100000
# 133 : 1111110000010000
# 134 : 0000000000000000
# 135 : 1111110010001000
# 136 : 0000000000000010
# 137 : 1111110000100000
# 138 : 1110001100001000
# 139 : 0000000000000010
# 140 : 1111110111010000
# 141 : 0000000000000000
# 142 : 1110001100001000
# 143 : 0000000000000101
# 144 : 1111110010100000
# 145 : 1111110000010000
# 146 : 0000000000000100
# 147 : 1110001100001000
# 148 : 0000000000000010
# 149 : 1110110000010000
# 150 : 0000000000000101
# 151 : 1111000111100000
# 152 : 1111110000010000
# 153 : 0000000000000011
# 154 : 1110001100001000
# 155 : 0000000000000011
# 156 : 1110110000010000
# 157 : 0000000000000101
# 158 : 1111000111100000
# 159 : 1111110000010000
# 160 : 0000000000000010
# 161 : 1110001100001000
# 162 : 0000000000000100
# 163 : 1110110000010000
# 164 : 0000000000000101
# 165 : 1111000111100000
# 166 : 1111110000010000
# 167 : 0000000000000001
# 168 : 1110001100001000
# 169 : 0000000000000110
# 170 : 1111110000100000
# 171 : 1110101010000111
# 172 : 0000000000000000
# 173 : 1110110000010000
# 174 : 0000000000000010
# 175 : 1111000010100000
# 176 : 1111110000010000
# 177 : 0000000000000000
# 178 : 1111110000100000
# 179 : 1110001100001000
# 180 : 0000000000000000
# 181 : 1111110111001000
# 182 : 0111111111111111
# 183 : 1110110000010000
# 184 : 0000000000000000
# 185 : 1111110000100000
# 186 : 1110001100001000
# 187 : 0000000000000000
# 188 : 1111110111001000
# 189 : 0000000000000000
# 190 : 1111110010100000
# 191 : 1111110000010000
# 192 : 0000000000000000
# 193 : 1111110010001000
# 194 : 0000000000000110
# 195 : 1110001100001000
# 196 : 0000000000000000
# 197 : 1111110010100000
# 198 : 1111110000010000
# 199 : 0000000000000000
# 200 : 1111110010001000
# 201 : 0000000000000101
# 202 : 1110001100001000
# 203 : 0000000000000101
# 204 : 1111110000010000
# 205 : 0000000000000110
# 206 : 1111000010010000
# 207 : 0000000000000000
# 208 : 1111110000100000
# 209 : 1110001100001000
# 210 : 0000000000000000
# 211 : 1111110111001000
# 212 : 0000000000000001
# 213 : 1110110000010000
# 214 : 0000000000000010
# 215 : 1111000010100000
# 216 : 1111110000010000
# 217 : 0000000000000000
# 218 : 1111110000100000
# 219 : 1110001100001000
# 220 : 0000000000000000
# 221 : 1111110111001000
# 222 : 0000000100001111
# 223 : 1110110000010000
# 224 : 0000000000000000
# 225 : 1111110000100000
# 226 : 1110001100001000
# 227 : 0000000000000000
# 228 : 1111110111001000
# 229 : 0000000000000001
# 230 : 1111110000010000
# 231 : 0000000000000000
# 232 : 1111110000100000
# 233 : 1110001100001000
# 234 : 0000000000000000
# 235 : 1111110111001000
# 236 : 0000000000000010
# 237 : 1111110000010000
# 238 : 0000000000000000
# 239 : 1111110000100000
# 240 : 1110001100001000
# 241 : 0000000000000000
# 242 : 1111110111001000
# 243 : 0000000000000011
# 244 : 1111110000010000
# 245 : 0000000000000000
# 246 : 1111110000100000
# 247 : 1110001100001000
# 248 : 0000000000000000
# 249 : 1111110111001000
# 250 : 0000000000000100
# 251 : 1111110000010000
# 252 : 0000000000000000
# 253 : 1111110000100000
# 254 : 1110001100001000
# 255 : 0000000000000000
# 256 : 1111110111001000
# 257 : 0000000000000000
# 258 : 1111110000010000
# 259 : 0000000000000010
# 260 : 1110010011010000
# 261 : 0000000000000101
# 262 : 1110010011010000
# 263 : 0000000000000010
# 264 : 1110001100001000
# 265 : 0000000000000000
# 266 : 1111110000010000
# 267 : 0000000000000001
# 268 : 1110001100001000
# 269 : 0000000000110111
# 270 : 1110101010000111
# 271 : 0000000000000001
# 272 : 1110110000010000
# 273 : 0000000000000010
# 274 : 1111000010100000
# 275 : 1111110000010000
# 276 : 0000000000000000
# 277 : 1111110000100000
# 278 : 1110001100001000
# 279 : 0000000000000000
# 280 : 1111110111001000
# 281 : 0000000000000000
# 282 : 1111110010100000
# 283 : 1111110000010000
# 284 : 0000000000000000
# 285 : 1111110010001000
# 286 : 0000000000000110
# 287 : 1110001100001000
# 288 : 0000000000000000
# 289 : 1111110010100000
# 290 : 1111110000010000
# 291 : 0000000000000000
# 292 : 1111110010001000
# 293 : 0000000000000101
# 294 : 1110001100001000
# 295 : 0000000000000101
# 296 : 1111110000010000
# 297 : 0000000000000110
# 298 : 1111000010010000
# 299 : 0000000000000000
# 300 : 1111110000100000
# 301 : 1110001100001000
# 302 : 0000000000000000
# 303 : 1111110111001000
# 304 : 0000000000000001
# 305 : 1111110000010000
# 306 : 0000000000000101
# 307 : 1110001100011000
# 308 : 0000000000000101
# 309 : 1110010011100000
# 310 : 1111110000010000
# 311 : 0000000000000110
# 312 : 1110001100001000
# 313 : 0000000000000000
# 314 : 1111110010100000
# 315 : 1111110000010000
# 316 : 0000000000000000
# 317 : 1111110010001000
# 318 : 0000000000000010
# 319 : 1111110000100000
# 320 : 1110001100001000
# 321 : 0000000000000010
# 322 : 1111110111010000
# 323 : 0000000000000000
# 324 : 1110001100001000
# 325 : 0000000000000101
# 326 : 1111110010100000
# 327 : 1111110000010000
# 328 : 0000000000000100
# 329 : 1110001100001000
# 330 : 0000000000000010
# 331 : 1110110000010000
# 332 : 0000000000000101
# 333 : 1111000111100000
# 334 : 1111110000010000
# 335 : 0000000000000011
# 336 : 1110001100001000
# 337 : 0000000000000011
# 338 : 1110110000010000
# 339 : 0000000000000101
# 340 : 1111000111100000
# 341 : 1111110000010000
# 342 : 0000000000000010
# 343 : 1110001100001000
# 344 : 0000000000000100
# 345 : 1110110000010000
# 346 : 0000000000000101
# 347 : 1111000111100000
# 348 : 1111110000010000
# 349 : 0000000000000001
# 350 : 1110001100001000
# 351 : 0000000000000110
# 352 : 1111110000100000
# 353 : 1110101010000111
# 354 : 0000000000000011
# 355 : 1110110000010000
# 356 : 0000000000000000
# 357 : 1111110000100000
# 358 : 1110001100001000
# 359 : 0000000000000000
# 360 : 1111110111001000
# 361 : 0000000000000100
# 362 : 1110110000010000
# 363 : 0000000000000000
# 364 : 1111110000100000
# 365 : 1110001100001000
# 366 : 0000000000000000
# 367 : 1111110111001000
# 368 : 0000000110100001
# 369 : 1110110000010000
# 370 : 0000000000000000
# 371 : 1111110000100000
# 372 : 1110001100001000
# 373 : 0000000000000000
# 374 : 1111110111001000
# 375 : 0000000000000001
# 376 : 1111110000010000
# 377 : 0000000000000000
# 378 : 1111110000100000
# 379 : 1110001100001000
# 380 : 0000000000000000
# 381 : 1111110111001000
# 382 : 0000000000000010
# 383 : 1111110000010000
# 384 : 0000000000000000
# 385 : 1111110000100000
# 386 : 1110001100001000
# 387 : 0000000000000000
# 388 : 1111110111001000
# 389 : 0000000000000011
# 390 : 1111110000010000
# 391 : 0000000000000000
# 392 : 1111110000100000
# 393 : 1110001100001000
# 394 : 0000000000000000
# 395 : 1111110111001000
# 396 : 0000000000000100
# 397 : 1111110000010000
# 398 : 0000000000000000
# 399 : 1111110000100000
# 400 : 1110001100001000
# 401 : 0000000000000000
# 402 : 1111110111001000
# 403 : 0000000000000000
# 404 : 1111110000010000
# 405 : 0000000000000010
# 406 : 1110010011010000
# 407 : 0000000000000101
# 408 : 1110010011010000
# 409 : 0000000000000010
# 410 : 1110001100001000
# 411 : 0000000000000000
# 412 : 1111110000010000
# 413 : 0000000000000001
# 414 : 1110001100001000
# 415 : 0000000000110111
# 416 : 1110101010000111
# 417 : 0000000000000001
# 418 : 1111110000010000
# 419 : 0000000000000101
# 420 : 1110001100011000
# 421 : 0000000000000101
# 422 : 1110010011100000
# 423 : 1111110000010000
# 424 : 0000000000000110
# 425 : 1110001100001000
# 426 : 0000000000000000
# 427 : 1111110010100000
# 428 : 1111110000010000
# 429 : 0000000000000000
# 430 : 1111110010001000
# 431 : 0000000000000010
# 432 : 1111110000100000
# 433 : 1110001100001000
# 434 : 0000000000000010
# 435 : 1111110111010000
# 436 : 0000000000000000
# 437 : 1110001100001000
# 438 : 0000000000000101
# 439 : 1111110010100000
# 440 : 1111110000010000
# 441 : 0000000000000100
# 442 : 1110001100001000
# 443 : 0000000000000010
# 444 : 1110110000010000
# 445 : 0000000000000101
# 446 : 1111000111100000
# 447 : 1111110000010000
# 448 : 0000000000000011
# 449 : 1110001100001000
# 450 : 0000000000000011
# 451 : 1110110000010000
# 452 : 0000000000000101
# 453 : 1111000111100000
# 454 : 1111110000010000
# 455 : 0000000000000010
# 456 : 1110001100001000
# 457 : 0000000000000100
# 458 : 1110110000010000
# 459 : 0000000000000101
# 460 : 1111000111100000
# 461 : 1111110000010000
# 462 : 0000000000000001
# 463 : 1110001100001000
# 464 : 0000000000000110
# 465 : 1111110000100000
# 466 : 1110101010000111
# ==============================
# Machine step 0
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): -256
# stack: []
# instr 0: @256, src_ref: (('psuedo code file', 0), '@256', '@256')
# Machine step 1
# D: 0, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): -256
# stack: []
# instr 1: D=A;null, src_ref: (('psuedo code file', 1), 'D=A', 'D=A')
# Machine step 2
# D: 256, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): -256
# stack: []
# instr 2: @0, src_ref: (('psuedo code file', 2), '@SP', '@SP')
# Machine step 3
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): -256
# stack: []
# instr 3: M=D;null, src_ref: (('psuedo code file', 3), 'M=D', 'M=D')
# Machine step 4
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 4: @53, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@0return-address')
# Machine step 5
# D: 256, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 5: D=A;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=A')
# Machine step 6
# D: 53, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 6: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 7
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 7: A=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'A=M')
# Machine step 8
# D: 53, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 8: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 9
# D: 53, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 9: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 10
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 0
# stack: []
# instr 10: M=M+1;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=M+1')
# Machine step 11
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 11: @1, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@LCL')
# Machine step 12
# D: 53, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 12: D=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=M')
# Machine step 13
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 13: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 14
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 14: A=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'A=M')
# Machine step 15
# D: 0, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 15: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 16
# D: 0, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 16: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 17
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [53]
# instr 17: M=M+1;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=M+1')
# Machine step 18
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 18: @2, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@ARG')
# Machine step 19
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 19: D=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=M')
# Machine step 20
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 20: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 21
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 21: A=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'A=M')
# Machine step 22
# D: 0, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 22: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 23
# D: 0, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 23: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 24
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 2
# stack: [53, 0]
# instr 24: M=M+1;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=M+1')
# Machine step 25
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 25: @3, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@THIS')
# Machine step 26
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 26: D=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=M')
# Machine step 27
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 27: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 28
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 28: A=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'A=M')
# Machine step 29
# D: 0, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 29: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 30
# D: 0, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 30: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 31
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 3
# stack: [53, 0, 0]
# instr 31: M=M+1;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=M+1')
# Machine step 32
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 32: @4, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@THAT')
# Machine step 33
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 33: D=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=M')
# Machine step 34
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 34: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 35
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 35: A=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'A=M')
# Machine step 36
# D: 0, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 36: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 37
# D: 0, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 37: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 38
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 4
# stack: [53, 0, 0, 0]
# instr 38: M=M+1;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=M+1')
# Machine step 39
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 39: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 40
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 40: D=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=M')
# Machine step 41
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 41: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@0')
# Machine step 42
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 42: D=D-A;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=D-A')
# Machine step 43
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 43: @5, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@5')
# Machine step 44
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 44: D=D-A;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=D-A')
# Machine step 45
# D: 256, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 45: @2, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@ARG')
# Machine step 46
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 46: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D')
# Machine step 47
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 47: @0, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@SP')
# Machine step 48
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 48: D=M;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'D=M')
# Machine step 49
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 49: @1, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@LCL')
# Machine step 50
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 0, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 50: M=D;null, src_ref: (('psuedo code file', 4), 'call Sys.init 0', 'M=D')
# Machine step 51
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 51: @354, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '@Sys.init')
# Machine step 52
# D: 261, A: 354, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 52: null=0;JMP, src_ref: (('psuedo code file', 4), 'call Sys.init 0', '0;JMP')
# Machine step 53
# D: 261, A: 354, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 354: @3, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', '@3')
# Machine step 54
# D: 261, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 355: D=A;null, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', 'D=A')
# Machine step 55
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 356: @0, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', '@SP')
# Machine step 56
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 357: A=M;null, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', 'A=M')
# Machine step 57
# D: 3, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 358: M=D;null, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 58
# D: 3, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 359: @0, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', '@SP')
# Machine step 59
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 360: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 26), 'push constant 3', 'M=M+1')
# Machine step 60
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 361: @4, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', '@4')
# Machine step 61
# D: 3, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 362: D=A;null, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', 'D=A')
# Machine step 62
# D: 4, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 363: @0, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', '@SP')
# Machine step 63
# D: 4, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 364: A=M;null, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', 'A=M')
# Machine step 64
# D: 4, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 365: M=D;null, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 65
# D: 4, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 366: @0, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', '@SP')
# Machine step 66
# D: 4, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 3]
# instr 367: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 27), 'push constant 4', 'M=M+1')
# Machine step 67
# D: 4, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 368: @417, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@4return-address')
# Machine step 68
# D: 4, A: 417, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 369: D=A;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=A')
# Machine step 69
# D: 417, A: 417, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 370: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 70
# D: 417, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 371: A=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'A=M')
# Machine step 71
# D: 417, A: 263, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 372: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 72
# D: 417, A: 263, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 373: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 73
# D: 417, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 7
# stack: [53, 0, 0, 0, 0, 3, 4]
# instr 374: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=M+1')
# Machine step 74
# D: 417, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 375: @1, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@LCL')
# Machine step 75
# D: 417, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 376: D=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=M')
# Machine step 76
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 377: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 77
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 378: A=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'A=M')
# Machine step 78
# D: 261, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 379: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 79
# D: 261, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 380: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 80
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 8
# stack: [53, 0, 0, 0, 0, 3, 4, 417]
# instr 381: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=M+1')
# Machine step 81
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 382: @2, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@ARG')
# Machine step 82
# D: 261, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 383: D=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=M')
# Machine step 83
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 384: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 84
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 385: A=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'A=M')
# Machine step 85
# D: 256, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 386: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 86
# D: 256, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 387: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 87
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 9
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261]
# instr 388: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=M+1')
# Machine step 88
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 389: @3, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@THIS')
# Machine step 89
# D: 256, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 390: D=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=M')
# Machine step 90
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 391: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 91
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 392: A=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'A=M')
# Machine step 92
# D: 0, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 393: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 93
# D: 0, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 394: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 94
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 10
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256]
# instr 395: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=M+1')
# Machine step 95
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 396: @4, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@THAT')
# Machine step 96
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 397: D=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=M')
# Machine step 97
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 398: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 98
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 399: A=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'A=M')
# Machine step 99
# D: 0, A: 267, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 400: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 100
# D: 0, A: 267, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 401: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 101
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 11
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0]
# instr 402: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=M+1')
# Machine step 102
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 403: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 103
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 404: D=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=M')
# Machine step 104
# D: 268, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 405: @2, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@2')
# Machine step 105
# D: 268, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 406: D=D-A;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=D-A')
# Machine step 106
# D: 266, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 407: @5, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@5')
# Machine step 107
# D: 266, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 408: D=D-A;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=D-A')
# Machine step 108
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 409: @2, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@ARG')
# Machine step 109
# D: 261, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 410: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D')
# Machine step 110
# D: 261, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 411: @0, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@SP')
# Machine step 111
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 412: D=M;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'D=M')
# Machine step 112
# D: 268, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 413: @1, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@LCL')
# Machine step 113
# D: 268, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 261, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 414: M=D;null, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', 'M=D')
# Machine step 114
# D: 268, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 415: @55, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '@multNat')
# Machine step 115
# D: 268, A: 55, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 416: null=0;JMP, src_ref: (('vm_codes/recursion.vm', 28), 'call multNat 2', '0;JMP')
# Machine step 116
# D: 268, A: 55, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 55: @0, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', '@0')
# Machine step 117
# D: 268, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 56: D=A;null, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', 'D=A')
# Machine step 118
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 57: @2, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', '@ARG')
# Machine step 119
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 58: A=D+M;null, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', 'A=D+M')
# Machine step 120
# D: 0, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 59: D=M;null, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', 'D=M')
# Machine step 121
# D: 3, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 60: @0, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', '@SP')
# Machine step 122
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 61: A=M;null, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', 'A=M')
# Machine step 123
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 62: M=D;null, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 124
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 63: @0, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', '@SP')
# Machine step 125
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 64: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 3), 'push argument 0', 'M=M+1')
# Machine step 126
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 65: @0, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', '@0')
# Machine step 127
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 66: D=A;null, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', 'D=A')
# Machine step 128
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 67: @0, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', '@SP')
# Machine step 129
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 68: A=M;null, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', 'A=M')
# Machine step 130
# D: 0, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 69: M=D;null, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 131
# D: 0, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 70: @0, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', '@SP')
# Machine step 132
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 71: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 4), 'push constant 0', 'M=M+1')
# Machine step 133
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 14
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3, 0]
# instr 72: @0, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@SP')
# Machine step 134
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 14
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3, 0]
# instr 73: A=M-1;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'A=M-1')
# Machine step 135
# D: 0, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 14
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3, 0]
# instr 74: D=M;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 136
# D: 0, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 14
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3, 0]
# instr 75: @0, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@SP')
# Machine step 137
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 14
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3, 0]
# instr 76: M=M-1;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 138
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 77: @6, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@6')
# Machine step 139
# D: 0, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 78: M=D;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'M=D')
# Machine step 140
# D: 0, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 79: @0, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@SP')
# Machine step 141
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 80: A=M-1;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'A=M-1')
# Machine step 142
# D: 0, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 81: D=M;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 143
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 82: @0, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@SP')
# Machine step 144
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, 3]
# instr 83: M=M-1;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 145
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 84: @5, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@5')
# Machine step 146
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 85: M=D;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'M=D')
# Machine step 147
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 86: @5, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@5')
# Machine step 148
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 87: D=M;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'D=M')
# Machine step 149
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 88: @6, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@6')
# Machine step 150
# D: 3, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 89: D=D-M;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'D=D-M')
# Machine step 151
# D: 3, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 90: @101, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@1ADD_TRUE')
# Machine step 152
# D: 3, A: 101, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 91: null=D;JGT, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'D;JGT')
# Machine step 153
# D: 3, A: 101, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 101: @-1, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@-1')
# Machine step 154
# D: 3, A: -1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 102: D=A;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'D=A')
# Machine step 155
# D: -1, A: -1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 103: @0, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@SP')
# Machine step 156
# D: -1, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 104: A=M;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'A=M')
# Machine step 157
# D: -1, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 105: M=D;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'M=D // M[M[SP]] is the tip of stack')
# Machine step 158
# D: -1, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 106: @0, src_ref: (('vm_codes/recursion.vm', 6), 'gt', '@SP')
# Machine step 159
# D: -1, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 107: M=M+1;null, src_ref: (('vm_codes/recursion.vm', 6), 'gt', 'M=M+1')
# Machine step 160
# D: -1, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, -1]
# instr 108: @0, src_ref: (('vm_codes/recursion.vm', 7), 'if-goto recurse', '@SP')
# Machine step 161
# D: -1, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, -1]
# instr 109: A=M-1;null, src_ref: (('vm_codes/recursion.vm', 7), 'if-goto recurse', 'A=M-1')
# Machine step 162
# D: -1, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, -1]
# instr 110: D=M;null, src_ref: (('vm_codes/recursion.vm', 7), 'if-goto recurse', 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 163
# D: -1, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, -1]
# instr 111: @0, src_ref: (('vm_codes/recursion.vm', 7), 'if-goto recurse', '@SP')
# Machine step 164
# D: -1, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 13
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0, -1]
# instr 112: M=M-1;null, src_ref: (('vm_codes/recursion.vm', 7), 'if-goto recurse', 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 165
# D: -1, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# stack: [53, 0, 0, 0, 0, 3, 4, 417, 261, 256, 0, 0]
# instr 113: @172, src_ref: (('vm_codes/recursion.vm', 7), 'if-goto recurse', '@multNat$recurse')
# Machine step 166
# D: -1, A: 172, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 12
# ...
# Machine step 903
# D: 2, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 332: @5, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@5')
# Machine step 904
# D: 2, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 333: A=M-D;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'A=M-D')
# Machine step 905
# D: 2, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 334: D=M;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'D=M')
# Machine step 906
# D: 0, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 335: @3, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@THIS')
# Machine step 907
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 336: M=D;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'M=D')
# Machine step 908
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 337: @3, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@3')
# Machine step 909
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 338: D=A;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'D=A')
# Machine step 910
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 339: @5, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@5')
# Machine step 911
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 340: A=M-D;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'A=M-D')
# Machine step 912
# D: 3, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 341: D=M;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'D=M')
# Machine step 913
# D: 256, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 342: @2, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@ARG')
# Machine step 914
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 261, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 343: M=D;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'M=D')
# Machine step 915
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 344: @4, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@4')
# Machine step 916
# D: 256, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 345: D=A;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'D=A')
# Machine step 917
# D: 4, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 346: @5, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@5')
# Machine step 918
# D: 4, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 347: A=M-D;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'A=M-D')
# Machine step 919
# D: 4, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 348: D=M;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'D=M')
# Machine step 920
# D: 261, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 349: @1, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@LCL')
# Machine step 921
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 268, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 350: M=D;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'M=D')
# Machine step 922
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 351: @6, src_ref: (('vm_codes/recursion.vm', 19), 'return', '@6')
# Machine step 923
# D: 261, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 352: A=M;null, src_ref: (('vm_codes/recursion.vm', 19), 'return', 'A=M')
# Machine step 924
# D: 261, A: 417, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 353: null=0;JMP, src_ref: (('vm_codes/recursion.vm', 19), 'return', '0;JMP')
# Machine step 925
# D: 261, A: 417, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 417: @1, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@LCL')
# Machine step 926
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 418: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M')
# Machine step 927
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 419: @5, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@5')
# Machine step 928
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 420: MD=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'MD=D')
# Machine step 929
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 421: @5, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@5')
# Machine step 930
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 422: A=D-A;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=D-A // M[temp+0]-5')
# Machine step 931
# D: 261, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 423: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M // M[M[temp+0]-5]')
# Machine step 932
# D: 53, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 424: @6, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@6')
# Machine step 933
# D: 53, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 425: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D')
# Machine step 934
# D: 53, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 426: @0, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@SP')
# Machine step 935
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 427: A=M-1;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M-1')
# Machine step 936
# D: 53, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 428: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 937
# D: 12, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 429: @0, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@SP')
# Machine step 938
# D: 12, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 6
# stack: [53, 0, 0, 0, 0, 12]
# instr 430: M=M-1;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 939
# D: 12, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 431: @2, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@ARG')
# Machine step 940
# D: 12, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 432: A=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M')
# Machine step 941
# D: 12, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [53, 0, 0, 0, 0]
# instr 433: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D // M[M[ARG]] = poped value')
# Machine step 942
# D: 12, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [12, 0, 0, 0, 0]
# instr 434: @2, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@ARG')
# Machine step 943
# D: 12, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [12, 0, 0, 0, 0]
# instr 435: D=M+1;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M+1')
# Machine step 944
# D: 257, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [12, 0, 0, 0, 0]
# instr 436: @0, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@SP')
# Machine step 945
# D: 257, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 5
# stack: [12, 0, 0, 0, 0]
# instr 437: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D')
# Machine step 946
# D: 257, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 438: @5, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@5')
# Machine step 947
# D: 257, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 439: A=M-1;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M-1')
# Machine step 948
# D: 257, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 440: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M')
# Machine step 949
# D: 0, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 441: @4, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@THAT')
# Machine step 950
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 442: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D')
# Machine step 951
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 443: @2, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@2')
# Machine step 952
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 444: D=A;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=A')
# Machine step 953
# D: 2, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 445: @5, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@5')
# Machine step 954
# D: 2, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 446: A=M-D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M-D')
# Machine step 955
# D: 2, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 447: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M')
# Machine step 956
# D: 0, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 448: @3, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@THIS')
# Machine step 957
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 449: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D')
# Machine step 958
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 450: @3, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@3')
# Machine step 959
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 451: D=A;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=A')
# Machine step 960
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 452: @5, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@5')
# Machine step 961
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 453: A=M-D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M-D')
# Machine step 962
# D: 3, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 454: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M')
# Machine step 963
# D: 0, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 455: @2, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@ARG')
# Machine step 964
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 256, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 456: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D')
# Machine step 965
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 457: @4, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@4')
# Machine step 966
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 458: D=A;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=A')
# Machine step 967
# D: 4, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 459: @5, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@5')
# Machine step 968
# D: 4, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 460: A=M-D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M-D')
# Machine step 969
# D: 4, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 461: D=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'D=M')
# Machine step 970
# D: 0, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 462: @1, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@LCL')
# Machine step 971
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 261, len(stack): 1
# stack: [12]
# instr 463: M=D;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'M=D')
# Machine step 972
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [12]
# instr 464: @6, src_ref: (('vm_codes/recursion.vm', 29), 'return', '@6')
# Machine step 973
# D: 0, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [12]
# instr 465: A=M;null, src_ref: (('vm_codes/recursion.vm', 29), 'return', 'A=M')
# Machine step 974
# D: 0, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [12]
# instr 466: null=0;JMP, src_ref: (('vm_codes/recursion.vm', 29), 'return', '0;JMP')
# Machine step 975
# D: 0, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [12]
# instr 53: @467, src_ref: (('psuedo code file', 5), '@0END', '@0END')
# Machine step 976
# D: 0, A: 467, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [12]
# instr 54: null=0;JMP, src_ref: (('psuedo code file', 6), '0;JMP', '0;JMP')
# Machine step 977
# D: 0, A: 467, M[16:20]: [0, 0, 0, 0] (static), M[ARG]: 0, M[LCL]: 0, len(stack): 1
# stack: [12]
# Finished execution
# Symbol table after execution
# ==============================
# Assembler(free_address=16, symbol_table=
# symbol    |address
# ---------------------
# SP        |0
# LCL       |1
# ARG       |2
# THIS      |3
# THAT      |4
# SCREEN    |16384
# KBD       |24576
# R0        |0
# R1        |1
# R2        |2
# R3        |3
# R4        |4
# R5        |5
# R6        |6
# R7        |7
# R8        |8
# R9        |9
# R10       |10
# R11       |11
# R12       |12
# R13       |13
# R14       |14
# R15       |15
# 0return-address|53
# multNat   |55
# 1ADD_TRUE |101
# 2cont     |108
# multNat$recurse|172
# 3return-address|271
# Sys.init  |354
# 4return-address|417
# 0END      |467
# )

# %% [markdown]
# # Potentially confusing ADD_TRUE symbol for comparision (>, =, <)
# adds '1'*16 instead of '0' + '1'*15, but doesn't lead to wrong result

# %%
dec2bin(65535, WORD_SIZE), dec2bin(32767, WORD_SIZE)
# Out:
# ('1111111111111111', '0111111111111111')

# %%
ass("@-1")
# Out:
# ('0111111111111111', [0])
