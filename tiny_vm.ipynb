# %% [markdown]
# # VM translator based on elements of computing systems
#
# ## The computed results should be at the top of the stack

# %%
import sys, os
from io import StringIO
from typing import List, Dict, Tuple
from enum import Enum
from functools import partial

# sys.path.append(os.path.join(os.path.dirname(__file__), "..", "lib"))
from lib.utils import pretty_format_dict, binary_or, binary_and, binary_add, binary_flip, binary_neg, WORD_SIZE
from lib.utils import bin2dec, print_with_lines

CommandType = Enum(
    'CommandType', 
    ['C_ARITHMETIC', # page 130, fig 7.5: e.g., add, sub, neg ...
     'C_PUSH', # page 131: push <segment> index, e.g., push argument 0 // stack.push(argument[0])
     'C_POP', # page 131: pop <segment> index, e.g., pop argment 0 // argment[0] = stack.pop()
     'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
     'C_GOTO',  # page 159: goto label, unconditional jump
     'C_IF', # page 159: if-goto label, pc = label if stack.pop() != 0 else pc + 1, label must be within the same function
     'C_FUNCTION', # page 163: function f k, where k is num local variables
     'C_RETURN', # page 163: return, return control to the caller
     'C_CALL', # page 163: call f n, where f is a function and n is number of arguments
    ]
)

ARITHMETIC_COMMANDS = ['add', 'sub', 'neg', 'eq', 'gt', 'lt', 'and', 'or', 'not']

def getCommandType(command: str)->CommandType:
    if command in ARITHMETIC_COMMANDS:
        return CommandType.C_ARITHMETIC
    elif command.startswith('push'):
        return CommandType.C_PUSH
    elif command.startswith('pop'):
        return CommandType.C_POP
    elif command.startswith('label'):
        return CommandType.C_LABEL
    elif command.startswith('goto'):
        return CommandType.C_GOTO
    elif command.startswith('if-goto'):
        return CommandType.C_IF
    elif command.startswith('function'):
        return CommandType.C_FUNCTION
    elif command.startswith('return'):
        return CommandType.C_RETURN
    elif command.startswith('call'):
        return CommandType.C_CALL
    
class Interpretor: 
    # AKA python machine that runs VM code
    '''VM interpretor, essentially a simulator in python
    instead of compiling the code, just run on the fly instead
    this is like the class Machine in assembler

    Here we assume VM only contain functions

    Interpreter is essentially a python machine
    where the hardware (including ROM) is specified by self.machine
    and machine language is python (the generated code is the concatenation
    of all the text in code execution parts of self.advance)
    '''
    def __init__(self, 
                 multi_line_comment_open:str='/*',
                 multi_line_comment_close:str='*/',
                 heap_size:int=5, temp_size:int=5, 
                 max_steps:int=100, verbose:bool=True):
        self.multi_line_comment_open = multi_line_comment_open
        self.multi_line_comment_close = multi_line_comment_close
        self.temp_size = temp_size
        self.heap_size = heap_size
        self.max_steps = max_steps
        self.verbose = verbose
        
    def load(self, vm_fnames: List[str]):
        self.machine = {
            'functions': {"Sys.psuedo_init": ["call Sys.init 0"]},
            'current_function': "Sys.psuedo_init",
            'pc': 0, # line number within current_function
            'stack': [], # page 141 M[256:2048]
            'heap': [0] * self.heap_size, # for storing objects, page 141 M[2048:16383]
            # 'sp': 0 # stack pointer: next top location in stack, page 142 R0, this need to be separately implemneted for hack machine but not for python
            'segments': {
                'argument': 0, # dynamically allocated per function, point to a cell on stack, page 142 R2
                'local': 0, # dynamically allocated per function, point to a cell on stack, page 142 R1
                'static': {}, # shared by all functions in the same .vm file, page 141 M[16:256]
                # 'constant': [], # psshared by all functions
                # 'this': [], # pointer to heap: pointer[0]
                # 'that': [], # pointer to heap: pointer[1]
                'pointer': [0, 0], # pointer to this and that, page 142 M[3:5]
                'temp': [0] * self.temp_size, # shared by all functions, page 142 M[5:13]
            }
        }

        # set up symbol lookup: symbol['current_function']['label'] -> 'pc'
        # b/c label in VM is attached to the function scope
        self.symbol_table = {}
        
        # populate functions and symbol table
        for fname in vm_fnames:
            with open(fname) as f:
                self._first_pass(f.readlines())

        if self.verbose:
            print('functions parsed')
            print(pretty_format_dict(self.machine['functions']))
            print('symbol table')
            print(pretty_format_dict(self.symbol_table))

        # make sure Sys.init is encountered
        assert self.machine['current_function'] in self.machine['functions'], f'{self.machine["current_function"]} need to be in vm code'

    def __repr__(self):
        return f'VM interpretor(Machine=\n{pretty_format_dict(self.machine)}\nSymbolTable=\n{pretty_format_dict(self.symbol_table)}\n)'

    def _first_pass(self, codes: List[str], in_comment:bool=False):
        # parse out all the functions into self.machine['functions'], add labels and function to symbol table,
        # and strip out comments
        # in_comment: are you in multi line comment /* */?
        func_name, func_codes = None, []
        lineno_within_func = 0

        for i, l in enumerate(codes):

            if in_comment:
                if self.multi_line_comment_close in l:
                    # comment closed
                    len_c_close = len(self.multi_line_comment_close)
                    l = l[l.index(self.multi_line_comment_close)+len_c_close:]
                    in_comment = False
                else:
                    # comment continue to open, ignore the line
                    continue
                    
            # sanitize line
            l = l.strip()
            orig_l = l
            if '//' in l: # comment
                l = l[:l.index('//')].strip()
            if self.multi_line_comment_open in l:
                in_comment = not orig_l.endswith(self.multi_line_comment_close)
                l = l[:l.index(self.multi_line_comment_open)].strip()
                
            # scrape function
            ct = getCommandType(l)
            if ct is CommandType.C_FUNCTION:
                if func_name is not None:
                    self.machine['functions'][func_name] = func_codes
                    return self._first_pass(codes[i:])
                else:
                    func_name = l.split()[1]
                    lineno_within_func += 1
                    if l != "": func_codes.append(l)

            elif ct is CommandType.C_LABEL:
                # 'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
                assert func_name is not None, f'label {l} need to be within a function'
                label = l.split()[1]
                if func_name not in self.symbol_table:
                    self.symbol_table[func_name] = {}
                self.symbol_table[func_name][label] = lineno_within_func
            else:
                lineno_within_func += 1
                if l != "": func_codes.append(l)
                
        if func_name is not None:
            self.machine['functions'][func_name] = func_codes
            return


    def advance(self)->bool:
        func_name, pc = self.machine['current_function'], self.machine['pc']
        codes = self.machine['functions'][func_name]

        if self.verbose:
            print('stack:', self.machine['stack'])
        
        if pc >= len(codes):
            # finished execution
            return False

        code = codes[pc]
        ct = getCommandType(code)
        if self.verbose:
            print(f'instruction {func_name}[{pc}]: {code}, type: {ct}')
        
        self.machine['pc'] += 1
        # instruction decoding and then execute
        stack = self.machine['stack']
        heap = self.machine['heap']
        segments = self.machine['segments']
        
        if ct is CommandType.C_ARITHMETIC:
            # 'C_ARITHMETIC', # page 130, fig 7.5: e.g., add, sub, neg ...
            x = self.machine['stack'].pop()
            if code in ['add', 'sub', 'eq', 'gt', 'lt', 'and', 'or']:
                # binary operators, TODO: rewrite some of them to bitwise operations 
                y = self.machine['stack'].pop()
                ret = {
                    'add': partial(binary_add, word_size=WORD_SIZE),
                    'sub': lambda a, b: a - b,
                    'eq': lambda a, b: a == b,
                    'gt': lambda a, b: a > b,
                    'lt': lambda a, b: a < b,
                    'and': partial(binary_and, word_size=WORD_SIZE),
                    'or': partial(binary_or, word_size=WORD_SIZE),
                }[code](x, y)
            else: 
                # unary operators
                ret = {
                    'neg': partial(binary_neg, word_size=WORD_SIZE),
                    'not': partial(binary_flip, word_size=WORD_SIZE),
                }[code](x)
                    
            self.machine['stack'].append(ret)
        elif ct is CommandType.C_PUSH:
            # 'C_PUSH', # page 131: push <segment> index, e.g., push argument 0 // stack.push(argument[0])
            _, segment, index = code.split()
            index = int(index)
            
            if segment == 'argument':
                # dynamically allocated per function, point to a cell on stack
                val = stack[segments[segment] + index]
            elif segment == 'local':
                # dynamically allocated per function, point to a cell on stack
                val = stack[segments[segment] + index]
            elif segment == 'static':
                # shared by all functions in the same .vm file, page 141 M[16:256]
                val = segments[segment][self.machine['current_function']][index]
            elif segment == 'constant':
                # shared by all functions
                val = index
            elif segment == 'this':
                # pointer to heap: pointer[0]
                val = heap[segment['pointer'][0] + index]
            elif segment == 'that':
                # pointer to heap: pointer[1]
                val = heap[segment['pointer'][1] + index]
            elif segment == 'pointer':
                # pointer to this and that, page 142 M[3:5]
                val = self.machine[segment][index]
            elif segment == 'temp':
                # shared by all functions, page 142 M[5:13]
                val = self.machine[segment][index]
            else:
                assert False, f'unknown segment {segment}'
                
            self.machine['stack'].append(val)
            
        elif ct is CommandType.C_POP:
            # 'C_POP', # page 131: pop <segment> index, e.g., pop argment 0 // argment[0] = stack.pop()
            _, segment, index = code.split()
            index = int(index)

            val = self.machine['stack'].pop()
            if segment == 'argument':
                # dynamically allocated per function, point to a cell on stack
                stack[segments[segment] + index] = val
            elif segment == 'local':
                # dynamically allocated per function, point to a cell on stack
                stack[segments[segment] + index] = val
            elif segment == 'static':
                # shared by all functions in .vm file, page 141 M[16:256]
                static_seg = segments[segment]
                curr_f = self.machine['current_function']
                if curr_f not in static_seg:
                    static_seg[curr_f] = [0] * (index+1)
                segments[segment][index] = val
            elif segment == 'constant':
                # shared by all functions
                assert False, 'cannot pop to constant'
            elif segment == 'this':
                # pointer to heap: pointer[0]
                heap[segment['pointer'][0] + index] = val
            elif segment == 'that':
                # pointer to heap: pointer[1]
                heap[segment['pointer'][1] + index] = val
            elif segment == 'pointer':
                # pointer to this and that, page 142 M[3:5]
                self.machine[segment][index] = val
            elif segment == 'temp':
                # shared by all functions, page 142 M[5:13]
                self.machine[segment][index] = val
            else:
                assert False, f'unknown segment {segment}'

        elif ct is CommandType.C_LABEL:
            # 'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
            assert False, f'{ct} command should only be encountered in _first_pass, as in this second pass it should have been resolved'
        elif ct is CommandType.C_GOTO:
            # 'C_GOTO',  # page 159: goto label, unconditional jump
            label = code.split()[1]
            assert label in self.symbol_table[self.machine['current_function']], f'{label} not in current function scope'
            self.machine['pc'] = self.symbol_table[self.machine['current_function']][label]
        elif ct is CommandType.C_IF: 
            # 'C_IF', # page 159: if-goto label, pc = label if stack.pop() != 0 else pc + 1, label must be within the same function
            label = code.split()[1]
            label_pc = self.symbol_table[self.machine['current_function']][label]
            if self.machine['stack'].pop() != 0:
                self.machine['pc'] = label_pc # no need to consider = 0 case b/c that's already default
        elif ct is CommandType.C_FUNCTION:
            # 'C_FUNCTION', # page 163: function f k, where k is num local variables
            n_local = int(code.split()[2])
            for _ in range(n_local):
                stack.append(0)
        elif ct is CommandType.C_RETURN:
            # 'C_RETURN', # page 163: return, return control to the caller
            frame = segments['local']
            prev_f, prev_f_lineno = stack[frame-5] # ret_addr for python machine it should be (), but for hack it will be a label to ROM
            # put return value back at the new top: see page 162, here I think the assumption is a function always returns something, could be None
            stack[segments['argument']] = stack.pop()
            sp = segments['argument'] + 1
            segments['pointer'] = [stack[frame-2], stack[frame-1]]
            segments['argument'] = stack[frame-3]
            segments['local'] = stack[frame-4]
            self.machine['stack'] = self.machine['stack'][:sp]

            # goto prev function
            self.machine['current_function'] = prev_f
            self.machine['pc'] = prev_f_lineno
        elif ct is CommandType.C_CALL:
            # 'C_CALL', # page 163: call f n, where f is a function and n is number of arguments
            _, next_f, n_args = code.split()
            n_args = int(n_args)
            # push return-address
            curr_f, pc = self.machine['current_function'], self.machine['pc']
            stack.append((curr_f, pc))
            # push lcl
            stack.append(segments['local'])
            # pushl arg
            stack.append(segments['argument'])
            # push this and that
            stack.extend(segments['pointer'])
            # arg = SP - n - 5
            segments['argument'] = len(stack) - n_args - 5
            # lcl = SP
            segments['local']= len(stack)
            # goto f
            self.machine['current_function'] = next_f
            self.machine['pc'] = 0
        else:
            assert False, f'command {ct} not found'
        
        return True

    
    def __call__(self, vm_fnames: List[str]):
        self.load(vm_fnames)

        steps = 0
        while steps <= self.max_steps:
            if self.verbose:
                print('Machine step', steps)
            steps += 1
            ok = self.advance()
            if not ok:
                print('Finished execution')
                return
        print(f'Program terminated b/c exceeding max step of {self.max_steps}')        

vm_interpretor = Interpretor()
vm_interpretor(['vm_codes/test.vm'])
# print(vm_interpretor)
# Out:
# functions parsed
# {
#     "Sys.psuedo_init": [
#         "call Sys.init 0"
#     ],
#     "double": [
#         "function double 0",
#         "push argument 0",
#         "push argument 0",
#         "add",
#         "return"
#     ],
#     "Sys.init": [
#         "function Sys.init 1",
#         "push constant 3",
#         "call double 1",
#         "pop local 0",
#         "return"
#     ]
# }
# symbol table
# {}
# Machine step 0
# stack: []
# instruction Sys.psuedo_init[0]: call Sys.init 0, type: CommandType.C_CALL
# Machine step 1
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0]
# instruction Sys.init[0]: function Sys.init 1, type: CommandType.C_FUNCTION
# Machine step 2
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0]
# instruction Sys.init[1]: push constant 3, type: CommandType.C_PUSH
# Machine step 3
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 3]
# instruction Sys.init[2]: call double 1, type: CommandType.C_CALL
# Machine step 4
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 3, ('Sys.init', 3), 5, 0, 0, 0]
# instruction double[0]: function double 0, type: CommandType.C_FUNCTION
# Machine step 5
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 3, ('Sys.init', 3), 5, 0, 0, 0]
# instruction double[1]: push argument 0, type: CommandType.C_PUSH
# Machine step 6
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 3, ('Sys.init', 3), 5, 0, 0, 0, 3]
# instruction double[2]: push argument 0, type: CommandType.C_PUSH
# Machine step 7
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 3, ('Sys.init', 3), 5, 0, 0, 0, 3, 3]
# instruction double[3]: add, type: CommandType.C_ARITHMETIC
# Machine step 8
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 3, ('Sys.init', 3), 5, 0, 0, 0, 6]
# instruction double[4]: return, type: CommandType.C_RETURN
# Machine step 9
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 0, 6]
# instruction Sys.init[3]: pop local 0, type: CommandType.C_POP
# Machine step 10
# stack: [('Sys.psuedo_init', 1), 0, 0, 0, 0, 6]
# instruction Sys.init[4]: return, type: CommandType.C_RETURN
# Machine step 11
# stack: [6]
# Finished execution

# %%
LanguageType = Enum(
    'LanguageType', 
    ['VM', 'ASSEMBLY']
)

def lineStrip(code:str)->List[str]:
    return list(filter(lambda x: x != "",
                       map(lambda x: x.strip(), code.split('\n'))))
    
class Translator:
    '''VM code -> Assembly code'''
    def __init__(self, 
                 multi_line_comment_open:str='/*',
                 multi_line_comment_close:str='*/',
                 temp_addr:int=5,
                 verbose:bool=True):
        self.multi_line_comment_open = multi_line_comment_open
        self.multi_line_comment_close = multi_line_comment_close
        self.n_symbol = 0 # used to track number of system symbol assigned
        self.current_function = None # useful for label: func_name$label
        self.temp_addr = temp_addr
        self.verbose = verbose
        
    def load(self, vm_fnames: List[str]):
        self.pc = 0 # where we are in the code
        self.sanitizedCodes = {} # fname -> {"codes", "linenos"}

        for fname in vm_fnames:
            with open(fname) as f:
                codes, linenos = self._sanitizeCodes(f.readlines())
                self.sanitizedCodes[fname] = {"codes": codes, "linenos": linenos}

        # insert initialization code, call Sys.init with no args
        # this is intermingled with direct assembly code for setting up 
        # utilities like symbols for setting up == operator
        self.compiledCodes = [
            # setup SP value to 256
            ('@256', LanguageType.ASSEMBLY),
            ('D=A', LanguageType.ASSEMBLY),
            ('@SP', LanguageType.ASSEMBLY),
            ('M=D', LanguageType.ASSEMBLY),
            # call initialization
            ("call Sys.init 0", LanguageType.VM),
            # jump to the end
            ("@0END", LanguageType.ASSEMBLY),
            ("0;JMP", LanguageType.ASSEMBLY),
        ]
        self.compiledLinenos = [("psuedo code file", i) for i in range(len(self.compiledCodes))]
        psuedo_lines = len(self.compiledCodes)

        # add back middle code
        for k, v in self.sanitizedCodes.items():
            self.compiledCodes.extend(
                zip(v["codes"], [LanguageType.VM] * len(v["codes"]))
            )
            for ln in v["linenos"]:
                self.compiledLinenos.append((k, ln))

        # jump to end of the code
        end_codes = [
            # start with number to differentiate from user label
            ("(0END)", LanguageType.ASSEMBLY),
        ]
        self.compiledCodes.extend(end_codes)
        self.compiledLinenos.extend([("psuedo code file", psuedo_lines+i) for i in range(len(end_codes))])

        if self.verbose:
            print('code sanitized')
            print('==============')
            print(pretty_format_dict(self.sanitizedCodes))
            print('compiled code')
            print('==============')
            print(self)
            print('==============')

    def __repr__(self):
        ret = ['VM translator(']
        for (code, langType), (fn, ln) in zip(self.compiledCodes, self.compiledLinenos):
            ret.append(f'({fn}, {ln}, {langType}): {code}')
        return "\n".join(ret + [')'])

    def _sanitizeCodes(self, codes: List[str])->Tuple[List[str], List[int]]:
        '''
        strip out comments e.g. // or /* comment */
        return (a list of command that are sanitized without comments, linenos in orignal code)
        '''
        def helper(codes:List[str], lineno:int, in_comment:bool, result: Tuple[List[str], List[int]])->Tuple[List[str], List[int]]:
            if len(codes) == 0:
                return result
            l, rest = codes[0], codes[1:]

            if in_comment:
                if self.multi_line_comment_close in l:
                    # comment closed
                    len_c_close = len(self.multi_line_comment_close)
                    l = l[l.index(self.multi_line_comment_close)+len_c_close:]
                    in_comment = False
                else:
                    # comment continue to open, ignore the line
                    return helper(rest, lineno+1, True, result)

            # sanitize line
            l = l.strip()
            orig_l = l
            if '//' in l: # comment
                l = l[:l.index('//')].strip()
            if self.multi_line_comment_open in l:
                in_comment = not orig_l.endswith(self.multi_line_comment_close)
                l = l[:l.index(self.multi_line_comment_open)].strip()

            if l == "":
                return helper(rest, lineno+1, in_comment, result)

            sanitized_codes, linenos = result
            return helper(rest, lineno+1, in_comment, (sanitized_codes + [l], linenos + [lineno]))
                        
        return helper(codes, 0, False, ([], []))

    def assignSystemSymbol(self)->int:
        self.n_symbol += 1
        return self.n_symbol - 1

    def _assPushD(self)->List[str]:
        '''push D to stack'''
        return lineStrip(
            '''
            @SP
            A=M
            M=D // M[M[SP]] is the tip of stack
            // M[SP] += 1
            @SP
            M=M+1
            '''
        )
        
    def _assPushA(self, s:str)->List[str]:
        '''push A=@s to stack in assembly code'''
        
        return [
            f'@{s}',
            'D=A',
        ] + self._assPushD()

    def _assPopToD(self)->List[str]:
        'pop stack to D'
        return lineStrip(
            '''
            // D=stack.pop()
            @SP
            A=M-1
            D=M // D=M[M[SP]-1] that is stack.top()
            @SP
            M=M-1 // M[SP] -= 1 // D=stack.pop()
            '''
        )
        
    def _assArithmetic(self, code:str)->List[str]:
        "given vm command output assembly codes"
        # 'C_ARITHMETIC', # page 130, fig 7.5: e.g., add, sub, neg ...
        # temp[0] = self.machine['stack'].pop()
        ass_codes = []
        temp = self.temp_addr
        ass_codes.extend(
            self._assPopToD() + lineStrip(
                f'''
                // M[temp+0]=D
                @{temp+0}
                M=D
                '''
            )
        )

        assert code in ARITHMETIC_COMMANDS, 'code invalid'
        if code in ['add', 'sub', 'eq', 'gt', 'lt', 'and', 'or']:
            # binary operators
            # temp[1] = self.machine['stack'].pop()
            ass_codes.extend(
                self._assPopToD() + lineStrip(
                    f'''
                    // M[temp+1]=D
                    @{temp+1}
                    M=D
                    '''
                )
            )

            # comput and push to stack
            if code == 'add':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        //* stack.push(temp[0] + temp[1])
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D+M
                        '''
                    ) + self._assPushD())
                
            elif code == 'sub':
                ass_codes.extend(
                    lineStrip(
                        '''
                        //* stack.push(temp[0] - temp[1])
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        '''
                    ) + self._assPushD())
            elif code == 'eq': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // temp[0]-temp[1] == 0
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        // test if eq 0
                        @{self.assignSystemSymbol()}ADD_TRUE
                        D;JEQ
                        // case for not true: push 0 and continue
                        '''
                    ) + self._assPushA('0') + lineStrip(
                        f'''
                        @{self.assignSystemSymbol()}cont
                        0;JMP
                        // case for true: push 0xF to top
                        ({self.n_symbol-2}ADD_TRUE)  
                        '''
                    ) + self._assPushA(bin2dec('1'*WORD_SIZE)) + lineStrip(
                        f'''
                        // continue
                        ({self.n_symbol-1}cont)
                        '''
                    ))
            elif code == 'gt': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // temp[0]-temp[1] > 0
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        // test if > 0
                        @{self.assignSystemSymbol()}ADD_TRUE
                        D;JGT
                        // case for not true: push 0 and continue
                        '''
                    ) + self._assPushA('0') + lineStrip(
                        f'''
                        @{self.assignSystemSymbol()}cont
                        0;JMP
                        // case for true: push 0xF to top
                        ({self.n_symbol-2}ADD_TRUE)  
                        '''
                    ) + self._assPushA(bin2dec('1'*WORD_SIZE)) + lineStrip(
                        f'''
                        // continue
                        ({self.n_symbol-1}cont)
                        '''
                    ))
            elif code == 'lt': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // temp[0]-temp[1] < 0
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D-M
                        // test if < 0
                        @{self.assignSystemSymbol()}ADD_TRUE
                        D;JLT
                        // case for not true: push 0 and continue
                        '''
                    ) + self._assPushA('0') + lineStrip(
                        f'''
                        @{self.assignSystemSymbol()}cont
                        0;JMP
                        // case for true: push 0xF to top
                        ({self.n_symbol-2}ADD_TRUE)  
                        '''
                    ) + self._assPushA(bin2dec('1'*WORD_SIZE)) + lineStrip(
                        f'''
                        // continue
                        ({self.n_symbol-1}cont)
                        '''
                    ))
            elif code == 'and': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // M[temp + 0] & M[temp + 1] and push to stack
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D&M
                        '''
                    ) + self._assPushD()
                )
            elif code == 'or': 
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // M[temp + 0] | M[temp + 1] and push to stack
                        @{temp+0}
                        D=M
                        @{temp+1}
                        D=D|M
                        '''
                    ) + self._assPushD()
                )
        else: 
            # unary operators
            if code == 'neg':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // -M[temp + 0]
                        @{temp+0}
                        D=-M
                        '''
                    ) + self._assPushD()
                )
            elif code == 'not':
                ass_codes.extend(
                    lineStrip(
                        f'''
                        // !M[temp + 0]
                        @{temp+0}
                        D=!M
                        '''
                    ) + self._assPushD()
                )
        return ass_codes

    def _assFunc(self, code:str)->List[str]:
        "given vm command output assembly codes"
        # 'C_FUNCTION', # page 163: function f k, where k is num local variables
        n_local = int(code.split()[2])
        func_name = code.split()[1]
        ass_codes = [f'({func_name})']
        for _ in range(n_local):
            ass_codes.extend(self._assPushA('0'))
        return ass_codes

    def _assCall(self, command:str)->List[str]:
        "given vm command output assembly codes"
        # # 'C_CALL', # page 163: call f n, where f is a function and n is number of arguments
        ass_codes = []
        _, next_f, n_args = command.split()
        n_args = int(n_args)
        # push return-address
        ass_codes.extend(self._assPushA(f'{self.assignSystemSymbol()}return-address'))
        # push M[lcl]
        ass_codes.extend(
            lineStrip(
                '''
                @LCL
                D=M
                '''
            ) + self._assPushD())
        # pushl M[arg]
        ass_codes.extend(
            lineStrip(
                '''
                @ARG
                D=M
                '''
            ) + self._assPushD())
        # push M[this] and M[that]
        ass_codes.extend(
            lineStrip(
                '''
                @THIS
                D=M
                '''
            ) + self._assPushD())
        ass_codes.extend(
            lineStrip(
                '''
                @THAT
                D=M
                '''
            ) + self._assPushD())
        # arg = SP - n_args - 5; 5 b/c we just pushed 5 elements
        ass_codes.extend([
            '@SP',
            'D=M',
            f'@{n_args}',
            'D=D-A',
            '@5',
            'D=D-A',
            '@ARG',
            'M=D',
        ])
        # lcl = SP; set local to the new function's local segment
        ass_codes.extend([
            '@SP',
            'D=M',
            '@LCL',
            'M=D',
        ])
        # goto f
        ass_codes.extend([
            f'@{next_f}',
            '0;JMP',
        ])
        ass_codes.append(f'({self.n_symbol-1}return-address)')
        return ass_codes

    def _assPop(self, code:str, fname:str)->List[str]:
        # 'C_POP', # page 131: pop <segment> index, e.g., pop argment 0 // argment[0] = stack.pop()
        _, segment, index = code.split()
        index = int(index)
        ret = self._assPopToD()
        
        if segment == 'argument':
            # dynamically allocated per function, point to a cell on stack
            ret += lineStrip(
                f'''
                // M[M[ARG]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @ARG
                D=D+M // M[ARG]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[ARG]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'local':
            # dynamically allocated per function, point to a cell on stack
            ret += lineStrip(
                f'''
                // M[M[LCL]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @LCL
                D=D+M // M[LCL]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[LCL]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'static':
            # shared by all functions in .vm file, page 141 M[16:256]            
            ret += lineStrip(
                f'''
                // M[fname.index] = stack.pop()
                @{fname}.{index}
                M=D
                '''
            )
        elif segment == 'constant':
            # shared by all functions
            assert False, 'cannot pop to constant'
        elif segment == 'this':
            ret += lineStrip(
                f'''
                // M[M[THIS]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @THIS
                D=D+M // M[THIS]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[THIS]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'that':
            ret += lineStrip(
                f'''
                // M[M[THAT]+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @THAT
                D=D+M // M[THAT]+index
                @{self.temp_addr+1}
                M=D // temp[1] = M[LCL]+index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'pointer':
            # pointer[0] and pointer[1] are this and that, page 142 M[3:5]
            ret += lineStrip(
                f'''
                // M[THIS+index] = stack.pop()
                @{self.temp_addr+0}
                M=D
                @{index}
                D=A
                @THIS
                D=D+A // THIS +index
                @{self.temp_addr+1}
                M=D // temp[1] = THIS +index
                @{self.temp_addr+0}
                D=M // retrieve saved top
                @{self.temp_addr+1}
                A=M
                M=D
                '''
            )
        elif segment == 'temp':
            # shared by all functions, page 142 M[5:13]
            ret += lineStrip(
                f'''
                // M[temp+index] = stack.pop()
                @{self.temp_addr+index}
                M=D
                '''
            )
        else:
            assert False, f'unknown segment {segment}'

        return ret

    def _assPush(self, code:str, fname:str)->List[str]:
        "given vm code output assembly codes; fname is the file where the command is from"
        # 'C_PUSH', # page 131: push <segment> index, e.g., push argument 0 // stack.push(argument[0])
        _, segment, index = code.split()
        index = int(index)

        # load value into D
        if segment == 'argument':
            # dynamically allocated per function, point to a cell on stack
            # D = M[M[ARG] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @ARG
                    A=D+M
                    // A is M[ARG] + index
                    D=M
                    '''
            )
        elif segment == 'local':
            # dynamically allocated per function, point to a cell on stack
            # D = M[M[LCL] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @LCL
                    A=D+M
                    // A is M[LCL] + index
                    D=M
                    '''
            )
        elif segment == 'static':
            # shared by all functions in XXX.vm file, page 141 M[16:256]
            # D = M[XXX.{index}]
            ret = lineStrip(
                    f'''
                    @{fname}.{index}
                    D=M
                    '''
            )
        elif segment == 'constant':
            # shared by all functions
            # D = index
            ret = [f'@{index}', 'D=A']
        elif segment == 'this':
            # pointer to heap: THIS
            # D = M[M[THIS] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @THIS
                    A=D+M
                    // A is M[THIS] + index
                    D=M
                    '''
            )
        elif segment == 'that':
            # pointer to heap: THAT
            # D = M[M[THAT] + index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @THAT
                    A=D+M
                    // A is M[THAT] + index
                    D=M
                    '''
            )
        elif segment == 'pointer':
            # pointer to this and that, page 142 M[3:5]
            # D = M[THIS+index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @THIS
                    A=D+A
                    D=M
                    '''
            )
        elif segment == 'temp':
            # shared by all functions, page 142 M[5:13]
            # D = M[R5+index]
            ret = lineStrip(
                    f'''
                    @{index}
                    D=A
                    @{self.temp_addr}
                    A=D+A
                    D=M
                    '''
            )
        else:
            assert False, f'unknown segment {segment}'
            
        return ret + self._assPushD()

    def _assReturn(self)->List[str]:
        # 'C_RETURN', # page 163: return, return control to the caller
        # stack looks like [arguments, prev_ret_addr, prev_local, prev_arg, prev_this, prev_that, lcl]
        # the new SP will be ARG+1 b/c ARG is where new returned value is
        return lineStrip(
            f'''
            // M[temp+0] = M[LCL]
            @LCL
            D=M
            @{self.temp_addr+0}
            MD=D
            // M[temp+1] = M[M[temp+0]-5] ; save return addr
            @5
            A=D-A // M[temp+0]-5
            D=M // M[M[temp+0]-5]
            @{self.temp_addr+1}
            M=D
            '''
        ) + self._assPopToD() + lineStrip(
            f'''
            // M[M[ARG]] = stack.pop(); pop the return value to arg segment
            @ARG
            A=M 
            M=D // M[M[ARG]] = poped value
            // M[SP] = M[ARG] + 1
            @ARG
            D=M+1
            @SP
            M=D
            // M[THAT] = M[M[TEMP+0]-1]
            @{self.temp_addr+0}
            A=M-1
            D=M
            @THAT
            M=D
            // M[THIS] = M[M[TEMP+0]-2]
            @2
            D=A
            @{self.temp_addr+0}
            A=M-D
            D=M
            @THIS
            M=D
            // M[ARG] = M[M[TEMP+0]-3]
            @3
            D=A
            @{self.temp_addr+0}
            A=M-D
            D=M
            @ARG
            M=D
            // M[LCL] = M[M[TEMP+0]-4]
            @4
            D=A
            @{self.temp_addr+0}
            A=M-D
            D=M
            @LCL
            M=D
            // goto M[temp+1]
            @{self.temp_addr+1}
            A=M
            0;JMP
            '''
        )

    def _assIf(code:str, func_name:str)->List[str]:
        # 'C_IF', # page 159: if-goto label, pc = label if stack.pop() != 0 else pc + 1, label must be within the same function
        label = code.split()[1]
        return self._assPopToD() + lineStrip(
            f'''
            @{func_name}${label}
            D;JNE
            '''
        )
        
    def _assGoto(code:str, func_name:str)->List[str]:
        # 'C_GOTO',  # page 159: goto label, unconditional jump
        label = code.split()[1]
        return lineStrip(
            f'''
            @{func_name}${label}
            0;JMP
            '''
        )

    def _assLabel(code:str, func_name:str)->List[str]:
        # 'C_LABEL', # page 159: label symbol, marks location in code, scope is within the function
        label = code.split()[1]
        return lineStrip(
            f'''
            ({func_name}${label})
            '''
        )
        
    def advance(self)->Tuple[bool, List[str], Tuple[str, int]]:
        '''
        return (ok, assembly codes for the next command, reference_line_in_orig_file)

        references in book:
        'pc': 0, # line number within current_function
        'stack': [], # page 141 M[256:2048]
        'heap': [0]*self.heap_size, # for storing objects, page 141 M[2048:16383]
        'sp': 0 # stack pointer: next top location in stack, page 142 R0
        'segments': {
            'argument': 0, # dynamically allocated per function, point to a cell on stack, page 142 R2
            'local': 0, # dynamically allocated per function, point to a cell on stack, page 142 R1
            'static': [0] * self.static_size, # shared by all functions in .vm file, page 141 M[16:256]
            'constant': [], # psshared by all functions
            'this': [], # pointer to heap: pointer[0]
            'that': [], # pointer to heap: pointer[1]
            'pointer': [0, 0], # pointer to this and that, page 142 M[3:5]
            'temp': [0] * self.temp_size, # shared by all functions, page 142 M[5:13]
        '''

        if self.pc >= len(self.compiledCodes):
            # finished execution
            return False, "", ("", 0)

        # instruction fetching
        code, langType = self.compiledCodes[self.pc]
        fname, code_lineno = self.compiledLinenos[self.pc]
        ct = getCommandType(code)
        self.pc += 1        
        if self.verbose:
            print(f'instruction from {fname}[{code_lineno}]: {code}, type: {ct}')

        if langType == LanguageType.ASSEMBLY:
            return True, [code], (fname, code_lineno)

        # instruction decoding and then execute
        ass_codes = []
        if ct is CommandType.C_ARITHMETIC:
            # page 130: add, neg, ...
            ass_codes.extend(self._assArithmetic(code))
        elif ct is CommandType.C_PUSH:
            # page 131: push <segment:e.g., local> <index: e.g., 1>
            ass_codes.extend(self._assPush(code, fname))
        elif ct is CommandType.C_POP:
            # page 131: pop <segment> index
            ass_codes.extend(self._assPop(code, fname))
        elif ct is CommandType.C_LABEL:
            # page 159: label symbol
            ass_codes.extend(self._assLabel(code, self.current_function))
        elif ct is CommandType.C_GOTO:
            # page 159: goto label
            ass_codes.extend(self._assGoto(code, self.current_function))
        elif ct is CommandType.C_IF:
            # if-goto label
            ass_codes.extend(self._assIf(code, self.current_function))
        elif ct is CommandType.C_FUNCTION:
            # page 163: function f k
            self.current_function = code.split()[1]
            ass_codes.extend(self._assFunc(code))
        elif ct is CommandType.C_RETURN:
            # page 163: return
            ass_codes.extend(self._assReturn())
        elif ct is CommandType.C_CALL:
            # page 163: call f n
            ass_codes.extend(self._assCall(code))
        else:
            assert False, f'command {ct} not founc'

        return True, ass_codes, (fname, code_lineno)
    
    def __call__(self, vm_fnames: List[str])->Tuple[str, List[Tuple[str, int]]]:
        '''
        given vm code in vm_fnames, 
        return (assembly_code, vm_code_lines that corresponds to assembly_code for debug)
        '''
        self.load(vm_fnames)

        codes = []
        linenos = []
        while True:
            ok, ass_codes, lineno = self.advance()
            if not ok: break
            codes.append(ass_codes)
            linenos.append(lineno)

        # build assembly line to vm line dictionary
        tgtRef2srcRef = []
        for (fname, i), codeLines in zip(linenos, codes):
            tgtRef2srcRef.extend([(fname, i)] * len(codeLines))
            
        return '\n'.join(['\n'.join(codeLines) for codeLines in codes]), tgtRef2srcRef

# %%
vm_translator = Translator()
# generated_code, assLine2vmLine = vm_translator(['vm_codes/add_const.vm'])
generated_code, assLine2vmLine = vm_translator(['vm_codes/test.vm'])
print('=========')
print_with_lines(generated_code)
# Out:
# code sanitized
# ==============
# {
#     "vm_codes/test.vm": {
#         "codes": [
#             "function double 0",
#             "push argument 0",
#             "push argument 0",
#             "add",
#             "return",
#             "function Sys.init 1",
#             "push constant 3",
#             "call double 1",
#             "pop local 0",
#             "return"
#         ],
#         "linenos": [
#             0,
#             2,
#             3,
#             4,
#             5,
#             7,
#             13,
#             14,
#             16,
#             17
#         ]
#     }
# }
# compiled code
# ==============
# VM translator(
# (psuedo code file, 0, LanguageType.ASSEMBLY): @256
# (psuedo code file, 1, LanguageType.ASSEMBLY): D=A
# (psuedo code file, 2, LanguageType.ASSEMBLY): @SP
# (psuedo code file, 3, LanguageType.ASSEMBLY): M=D
# (psuedo code file, 4, LanguageType.VM): call Sys.init 0
# (psuedo code file, 5, LanguageType.ASSEMBLY): @0END
# (psuedo code file, 6, LanguageType.ASSEMBLY): 0;JMP
# (vm_codes/test.vm, 0, LanguageType.VM): function double 0
# (vm_codes/test.vm, 2, LanguageType.VM): push argument 0
# (vm_codes/test.vm, 3, LanguageType.VM): push argument 0
# (vm_codes/test.vm, 4, LanguageType.VM): add
# (vm_codes/test.vm, 5, LanguageType.VM): return
# (vm_codes/test.vm, 7, LanguageType.VM): function Sys.init 1
# (vm_codes/test.vm, 13, LanguageType.VM): push constant 3
# (vm_codes/test.vm, 14, LanguageType.VM): call double 1
# (vm_codes/test.vm, 16, LanguageType.VM): pop local 0
# (vm_codes/test.vm, 17, LanguageType.VM): return
# (psuedo code file, 7, LanguageType.ASSEMBLY): (0END)
# )
# ==============
# instruction from psuedo code file[0]: @256, type: None
# instruction from psuedo code file[1]: D=A, type: None
# instruction from psuedo code file[2]: @SP, type: None
# instruction from psuedo code file[3]: M=D, type: None
# instruction from psuedo code file[4]: call Sys.init 0, type: CommandType.C_CALL
# instruction from psuedo code file[5]: @0END, type: None
# instruction from psuedo code file[6]: 0;JMP, type: None
# instruction from vm_codes/test.vm[0]: function double 0, type: CommandType.C_FUNCTION
# instruction from vm_codes/test.vm[2]: push argument 0, type: CommandType.C_PUSH
# instruction from vm_codes/test.vm[3]: push argument 0, type: CommandType.C_PUSH
# instruction from vm_codes/test.vm[4]: add, type: CommandType.C_ARITHMETIC
# instruction from vm_codes/test.vm[5]: return, type: CommandType.C_RETURN
# instruction from vm_codes/test.vm[7]: function Sys.init 1, type: CommandType.C_FUNCTION
# instruction from vm_codes/test.vm[13]: push constant 3, type: CommandType.C_PUSH
# instruction from vm_codes/test.vm[14]: call double 1, type: CommandType.C_CALL
# instruction from vm_codes/test.vm[16]: pop local 0, type: CommandType.C_POP
# instruction from vm_codes/test.vm[17]: return, type: CommandType.C_RETURN
# instruction from psuedo code file[7]: (0END), type: None
# =========
# 0   : @256
# 1   : D=A
# 2   : @SP
# 3   : M=D
# 4   : @0return-address
# 5   : D=A
# 6   : @SP
# 7   : A=M
# 8   : M=D // M[M[SP]] is the tip of stack
# 9   : // M[SP] += 1
# 10  : @SP
# 11  : M=M+1
# 12  : @LCL
# 13  : D=M
# 14  : @SP
# 15  : A=M
# 16  : M=D // M[M[SP]] is the tip of stack
# 17  : // M[SP] += 1
# 18  : @SP
# 19  : M=M+1
# 20  : @ARG
# 21  : D=M
# 22  : @SP
# 23  : A=M
# 24  : M=D // M[M[SP]] is the tip of stack
# 25  : // M[SP] += 1
# 26  : @SP
# 27  : M=M+1
# 28  : @THIS
# 29  : D=M
# 30  : @SP
# 31  : A=M
# 32  : M=D // M[M[SP]] is the tip of stack
# 33  : // M[SP] += 1
# 34  : @SP
# 35  : M=M+1
# 36  : @THAT
# 37  : D=M
# 38  : @SP
# 39  : A=M
# 40  : M=D // M[M[SP]] is the tip of stack
# 41  : // M[SP] += 1
# 42  : @SP
# 43  : M=M+1
# 44  : @SP
# 45  : D=M
# 46  : @0
# 47  : D=D-A
# 48  : @5
# 49  : D=D-A
# 50  : @ARG
# 51  : M=D
# 52  : @SP
# 53  : D=M
# 54  : @LCL
# 55  : M=D
# 56  : @Sys.init
# 57  : 0;JMP
# 58  : (0return-address)
# 59  : @0END
# 60  : 0;JMP
# 61  : (double)
# 62  : @0
# 63  : D=A
# 64  : @ARG
# 65  : A=D+M
# 66  : // A is M[ARG] + index
# 67  : D=M
# 68  : @SP
# 69  : A=M
# 70  : M=D // M[M[SP]] is the tip of stack
# 71  : // M[SP] += 1
# 72  : @SP
# 73  : M=M+1
# 74  : @0
# 75  : D=A
# 76  : @ARG
# 77  : A=D+M
# 78  : // A is M[ARG] + index
# 79  : D=M
# 80  : @SP
# 81  : A=M
# 82  : M=D // M[M[SP]] is the tip of stack
# 83  : // M[SP] += 1
# 84  : @SP
# 85  : M=M+1
# 86  : // D=stack.pop()
# 87  : @SP
# 88  : A=M-1
# 89  : D=M // D=M[M[SP]-1] that is stack.top()
# 90  : @SP
# 91  : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 92  : // M[temp+0]=D
# 93  : @5
# 94  : M=D
# 95  : // D=stack.pop()
# 96  : @SP
# 97  : A=M-1
# 98  : D=M // D=M[M[SP]-1] that is stack.top()
# 99  : @SP
# 100 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 101 : // M[temp+1]=D
# 102 : @6
# 103 : M=D
# 104 : //* stack.push(temp[0] + temp[1])
# 105 : @5
# 106 : D=M
# 107 : @6
# 108 : D=D+M
# 109 : @SP
# 110 : A=M
# 111 : M=D // M[M[SP]] is the tip of stack
# 112 : // M[SP] += 1
# 113 : @SP
# 114 : M=M+1
# 115 : // M[temp+0] = M[LCL]
# 116 : @LCL
# 117 : D=M
# 118 : @5
# 119 : MD=D
# 120 : // M[temp+1] = M[M[temp+0]-5] ; save return addr
# 121 : @5
# 122 : A=D-A // M[temp+0]-5
# 123 : D=M // M[M[temp+0]-5]
# 124 : @6
# 125 : M=D
# 126 : // D=stack.pop()
# 127 : @SP
# 128 : A=M-1
# 129 : D=M // D=M[M[SP]-1] that is stack.top()
# 130 : @SP
# 131 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 132 : // M[M[ARG]] = stack.pop(); pop the return value to arg segment
# 133 : @ARG
# 134 : A=M
# 135 : M=D // M[M[ARG]] = poped value
# 136 : // M[SP] = M[ARG] + 1
# 137 : @ARG
# 138 : D=M+1
# 139 : @SP
# 140 : M=D
# 141 : // M[THAT] = M[M[TEMP+0]-1]
# 142 : @5
# 143 : A=M-1
# 144 : D=M
# 145 : @THAT
# 146 : M=D
# 147 : // M[THIS] = M[M[TEMP+0]-2]
# 148 : @2
# 149 : D=A
# 150 : @5
# 151 : A=M-D
# 152 : D=M
# 153 : @THIS
# 154 : M=D
# 155 : // M[ARG] = M[M[TEMP+0]-3]
# 156 : @3
# 157 : D=A
# 158 : @5
# 159 : A=M-D
# 160 : D=M
# 161 : @ARG
# 162 : M=D
# 163 : // M[LCL] = M[M[TEMP+0]-4]
# 164 : @4
# 165 : D=A
# 166 : @5
# 167 : A=M-D
# 168 : D=M
# 169 : @LCL
# 170 : M=D
# 171 : // goto M[temp+1]
# 172 : @6
# 173 : A=M
# 174 : 0;JMP
# 175 : (Sys.init)
# 176 : @0
# 177 : D=A
# 178 : @SP
# 179 : A=M
# 180 : M=D // M[M[SP]] is the tip of stack
# 181 : // M[SP] += 1
# 182 : @SP
# 183 : M=M+1
# 184 : @3
# 185 : D=A
# 186 : @SP
# 187 : A=M
# 188 : M=D // M[M[SP]] is the tip of stack
# 189 : // M[SP] += 1
# 190 : @SP
# 191 : M=M+1
# 192 : @1return-address
# 193 : D=A
# 194 : @SP
# 195 : A=M
# 196 : M=D // M[M[SP]] is the tip of stack
# 197 : // M[SP] += 1
# 198 : @SP
# 199 : M=M+1
# 200 : @LCL
# 201 : D=M
# 202 : @SP
# 203 : A=M
# 204 : M=D // M[M[SP]] is the tip of stack
# 205 : // M[SP] += 1
# 206 : @SP
# 207 : M=M+1
# 208 : @ARG
# 209 : D=M
# 210 : @SP
# 211 : A=M
# 212 : M=D // M[M[SP]] is the tip of stack
# 213 : // M[SP] += 1
# 214 : @SP
# 215 : M=M+1
# 216 : @THIS
# 217 : D=M
# 218 : @SP
# 219 : A=M
# 220 : M=D // M[M[SP]] is the tip of stack
# 221 : // M[SP] += 1
# 222 : @SP
# 223 : M=M+1
# 224 : @THAT
# 225 : D=M
# 226 : @SP
# 227 : A=M
# 228 : M=D // M[M[SP]] is the tip of stack
# 229 : // M[SP] += 1
# 230 : @SP
# 231 : M=M+1
# 232 : @SP
# 233 : D=M
# 234 : @1
# 235 : D=D-A
# 236 : @5
# 237 : D=D-A
# 238 : @ARG
# 239 : M=D
# 240 : @SP
# 241 : D=M
# 242 : @LCL
# 243 : M=D
# 244 : @double
# 245 : 0;JMP
# 246 : (1return-address)
# 247 : // D=stack.pop()
# 248 : @SP
# 249 : A=M-1
# 250 : D=M // D=M[M[SP]-1] that is stack.top()
# 251 : @SP
# 252 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 253 : // M[M[LCL]+index] = stack.pop()
# 254 : @5
# 255 : M=D
# 256 : @0
# 257 : D=A
# 258 : @LCL
# 259 : D=D+M // M[LCL]+index
# 260 : @6
# 261 : M=D // temp[1] = M[LCL]+index
# 262 : @5
# 263 : D=M // retrieve saved top
# 264 : @6
# 265 : A=M
# 266 : M=D
# 267 : // M[temp+0] = M[LCL]
# 268 : @LCL
# 269 : D=M
# 270 : @5
# 271 : MD=D
# 272 : // M[temp+1] = M[M[temp+0]-5] ; save return addr
# 273 : @5
# 274 : A=D-A // M[temp+0]-5
# 275 : D=M // M[M[temp+0]-5]
# 276 : @6
# 277 : M=D
# 278 : // D=stack.pop()
# 279 : @SP
# 280 : A=M-1
# 281 : D=M // D=M[M[SP]-1] that is stack.top()
# 282 : @SP
# 283 : M=M-1 // M[SP] -= 1 // D=stack.pop()
# 284 : // M[M[ARG]] = stack.pop(); pop the return value to arg segment
# 285 : @ARG
# 286 : A=M
# 287 : M=D // M[M[ARG]] = poped value
# 288 : // M[SP] = M[ARG] + 1
# 289 : @ARG
# 290 : D=M+1
# 291 : @SP
# 292 : M=D
# 293 : // M[THAT] = M[M[TEMP+0]-1]
# 294 : @5
# 295 : A=M-1
# 296 : D=M
# 297 : @THAT
# 298 : M=D
# 299 : // M[THIS] = M[M[TEMP+0]-2]
# 300 : @2
# 301 : D=A
# 302 : @5
# 303 : A=M-D
# 304 : D=M
# 305 : @THIS
# 306 : M=D
# 307 : // M[ARG] = M[M[TEMP+0]-3]
# 308 : @3
# 309 : D=A
# 310 : @5
# 311 : A=M-D
# 312 : D=M
# 313 : @ARG
# 314 : M=D
# 315 : // M[LCL] = M[M[TEMP+0]-4]
# 316 : @4
# 317 : D=A
# 318 : @5
# 319 : A=M-D
# 320 : D=M
# 321 : @LCL
# 322 : M=D
# 323 : // goto M[temp+1]
# 324 : @6
# 325 : A=M
# 326 : 0;JMP
# 327 : (0END)

# %%
from lib.assembler import Assembler, Machine

### translate assembly to machine code
ass = Assembler()
machine_codes, ass_linenos = ass(generated_code)

print('Machine code')
print('='*30)
print_with_lines(machine_codes)
print('='*30)

### execute machine code
machine = Machine(verbose=True, memory_size=1000, max_steps=300)
machine(machine_codes, 
        [(fn, i, generated_code.split('\n')[j])for (fn, i), j in zip(
            [assLine2vmLine[k] for k in ass_linenos], # select out codes without comment
            ass_linenos)]
       )

print('Symbol table after execution')
print('='*30)
print(ass)
# Out:
# Machine code
# ==============================
# 0   : 0000000100000000
# 1   : 1110110000010000
# 2   : 0000000000000000
# 3   : 1110001100001000
# 4   : 0000000000110101
# 5   : 1110110000010000
# 6   : 0000000000000000
# 7   : 1111110000100000
# 8   : 1110001100001000
# 9   : 0000000000000000
# 10  : 1111110111001000
# 11  : 0000000000000001
# 12  : 1111110000010000
# 13  : 0000000000000000
# 14  : 1111110000100000
# 15  : 1110001100001000
# 16  : 0000000000000000
# 17  : 1111110111001000
# 18  : 0000000000000010
# 19  : 1111110000010000
# 20  : 0000000000000000
# 21  : 1111110000100000
# 22  : 1110001100001000
# 23  : 0000000000000000
# 24  : 1111110111001000
# 25  : 0000000000000011
# 26  : 1111110000010000
# 27  : 0000000000000000
# 28  : 1111110000100000
# 29  : 1110001100001000
# 30  : 0000000000000000
# 31  : 1111110111001000
# 32  : 0000000000000100
# 33  : 1111110000010000
# 34  : 0000000000000000
# 35  : 1111110000100000
# 36  : 1110001100001000
# 37  : 0000000000000000
# 38  : 1111110111001000
# 39  : 0000000000000000
# 40  : 1111110000010000
# 41  : 0000000000000000
# 42  : 1110010011010000
# 43  : 0000000000000101
# 44  : 1110010011010000
# 45  : 0000000000000010
# 46  : 1110001100001000
# 47  : 0000000000000000
# 48  : 1111110000010000
# 49  : 0000000000000001
# 50  : 1110001100001000
# 51  : 0000000010010100
# 52  : 1110101010000111
# 53  : 0000000100010111
# 54  : 1110101010000111
# 55  : 0000000000000000
# 56  : 1110110000010000
# 57  : 0000000000000010
# 58  : 1111000010100000
# 59  : 1111110000010000
# 60  : 0000000000000000
# 61  : 1111110000100000
# 62  : 1110001100001000
# 63  : 0000000000000000
# 64  : 1111110111001000
# 65  : 0000000000000000
# 66  : 1110110000010000
# 67  : 0000000000000010
# 68  : 1111000010100000
# 69  : 1111110000010000
# 70  : 0000000000000000
# 71  : 1111110000100000
# 72  : 1110001100001000
# 73  : 0000000000000000
# 74  : 1111110111001000
# 75  : 0000000000000000
# 76  : 1111110010100000
# 77  : 1111110000010000
# 78  : 0000000000000000
# 79  : 1111110010001000
# 80  : 0000000000000101
# 81  : 1110001100001000
# 82  : 0000000000000000
# 83  : 1111110010100000
# 84  : 1111110000010000
# 85  : 0000000000000000
# 86  : 1111110010001000
# 87  : 0000000000000110
# 88  : 1110001100001000
# 89  : 0000000000000101
# 90  : 1111110000010000
# 91  : 0000000000000110
# 92  : 1111000010010000
# 93  : 0000000000000000
# 94  : 1111110000100000
# 95  : 1110001100001000
# 96  : 0000000000000000
# 97  : 1111110111001000
# 98  : 0000000000000001
# 99  : 1111110000010000
# 100 : 0000000000000101
# 101 : 1110001100011000
# 102 : 0000000000000101
# 103 : 1110010011100000
# 104 : 1111110000010000
# 105 : 0000000000000110
# 106 : 1110001100001000
# 107 : 0000000000000000
# 108 : 1111110010100000
# 109 : 1111110000010000
# 110 : 0000000000000000
# 111 : 1111110010001000
# 112 : 0000000000000010
# 113 : 1111110000100000
# 114 : 1110001100001000
# 115 : 0000000000000010
# 116 : 1111110111010000
# 117 : 0000000000000000
# 118 : 1110001100001000
# 119 : 0000000000000101
# 120 : 1111110010100000
# 121 : 1111110000010000
# 122 : 0000000000000100
# 123 : 1110001100001000
# 124 : 0000000000000010
# 125 : 1110110000010000
# 126 : 0000000000000101
# 127 : 1111000111100000
# 128 : 1111110000010000
# 129 : 0000000000000011
# 130 : 1110001100001000
# 131 : 0000000000000011
# 132 : 1110110000010000
# 133 : 0000000000000101
# 134 : 1111000111100000
# 135 : 1111110000010000
# 136 : 0000000000000010
# 137 : 1110001100001000
# 138 : 0000000000000100
# 139 : 1110110000010000
# 140 : 0000000000000101
# 141 : 1111000111100000
# 142 : 1111110000010000
# 143 : 0000000000000001
# 144 : 1110001100001000
# 145 : 0000000000000110
# 146 : 1111110000100000
# 147 : 1110101010000111
# 148 : 0000000000000000
# 149 : 1110110000010000
# 150 : 0000000000000000
# 151 : 1111110000100000
# 152 : 1110001100001000
# 153 : 0000000000000000
# 154 : 1111110111001000
# 155 : 0000000000000011
# 156 : 1110110000010000
# 157 : 0000000000000000
# 158 : 1111110000100000
# 159 : 1110001100001000
# 160 : 0000000000000000
# 161 : 1111110111001000
# 162 : 0000000011010011
# 163 : 1110110000010000
# 164 : 0000000000000000
# 165 : 1111110000100000
# 166 : 1110001100001000
# 167 : 0000000000000000
# 168 : 1111110111001000
# 169 : 0000000000000001
# 170 : 1111110000010000
# 171 : 0000000000000000
# 172 : 1111110000100000
# 173 : 1110001100001000
# 174 : 0000000000000000
# 175 : 1111110111001000
# 176 : 0000000000000010
# 177 : 1111110000010000
# 178 : 0000000000000000
# 179 : 1111110000100000
# 180 : 1110001100001000
# 181 : 0000000000000000
# 182 : 1111110111001000
# 183 : 0000000000000011
# 184 : 1111110000010000
# 185 : 0000000000000000
# 186 : 1111110000100000
# 187 : 1110001100001000
# 188 : 0000000000000000
# 189 : 1111110111001000
# 190 : 0000000000000100
# 191 : 1111110000010000
# 192 : 0000000000000000
# 193 : 1111110000100000
# 194 : 1110001100001000
# 195 : 0000000000000000
# 196 : 1111110111001000
# 197 : 0000000000000000
# 198 : 1111110000010000
# 199 : 0000000000000001
# 200 : 1110010011010000
# 201 : 0000000000000101
# 202 : 1110010011010000
# 203 : 0000000000000010
# 204 : 1110001100001000
# 205 : 0000000000000000
# 206 : 1111110000010000
# 207 : 0000000000000001
# 208 : 1110001100001000
# 209 : 0000000000110111
# 210 : 1110101010000111
# 211 : 0000000000000000
# 212 : 1111110010100000
# 213 : 1111110000010000
# 214 : 0000000000000000
# 215 : 1111110010001000
# 216 : 0000000000000101
# 217 : 1110001100001000
# 218 : 0000000000000000
# 219 : 1110110000010000
# 220 : 0000000000000001
# 221 : 1111000010010000
# 222 : 0000000000000110
# 223 : 1110001100001000
# 224 : 0000000000000101
# 225 : 1111110000010000
# 226 : 0000000000000110
# 227 : 1111110000100000
# 228 : 1110001100001000
# 229 : 0000000000000001
# 230 : 1111110000010000
# 231 : 0000000000000101
# 232 : 1110001100011000
# 233 : 0000000000000101
# 234 : 1110010011100000
# 235 : 1111110000010000
# 236 : 0000000000000110
# 237 : 1110001100001000
# 238 : 0000000000000000
# 239 : 1111110010100000
# 240 : 1111110000010000
# 241 : 0000000000000000
# 242 : 1111110010001000
# 243 : 0000000000000010
# 244 : 1111110000100000
# 245 : 1110001100001000
# 246 : 0000000000000010
# 247 : 1111110111010000
# 248 : 0000000000000000
# 249 : 1110001100001000
# 250 : 0000000000000101
# 251 : 1111110010100000
# 252 : 1111110000010000
# 253 : 0000000000000100
# 254 : 1110001100001000
# 255 : 0000000000000010
# 256 : 1110110000010000
# 257 : 0000000000000101
# 258 : 1111000111100000
# 259 : 1111110000010000
# 260 : 0000000000000011
# 261 : 1110001100001000
# 262 : 0000000000000011
# 263 : 1110110000010000
# 264 : 0000000000000101
# 265 : 1111000111100000
# 266 : 1111110000010000
# 267 : 0000000000000010
# 268 : 1110001100001000
# 269 : 0000000000000100
# 270 : 1110110000010000
# 271 : 0000000000000101
# 272 : 1111000111100000
# 273 : 1111110000010000
# 274 : 0000000000000001
# 275 : 1110001100001000
# 276 : 0000000000000110
# 277 : 1111110000100000
# 278 : 1110101010000111
# ==============================
# Machine step 0
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[-5: M[SP]=0]: f[] (stack)
# instr 0: @256, src_ref: ('psuedo code file', 0, '@256')
# Machine step 1
# D: 0, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[-5: M[SP]=0]: f[] (stack)
# instr 1: D=A;null, src_ref: ('psuedo code file', 1, 'D=A')
# Machine step 2
# D: 256, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[-5: M[SP]=0]: f[] (stack)
# instr 2: @0, src_ref: ('psuedo code file', 2, '@SP')
# Machine step 3
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[-5: M[SP]=0]: f[] (stack)
# instr 3: M=D;null, src_ref: ('psuedo code file', 3, 'M=D')
# Machine step 4
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 4: @53, src_ref: ('psuedo code file', 4, '@0return-address')
# Machine step 5
# D: 256, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 5: D=A;null, src_ref: ('psuedo code file', 4, 'D=A')
# Machine step 6
# D: 53, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 6: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 7
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 7: A=M;null, src_ref: ('psuedo code file', 4, 'A=M')
# Machine step 8
# D: 53, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 8: M=D;null, src_ref: ('psuedo code file', 4, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 9
# D: 53, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 9: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 10
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[251: M[SP]=256]: f[0, 0, 0, 0, 0] (stack)
# instr 10: M=M+1;null, src_ref: ('psuedo code file', 4, 'M=M+1')
# Machine step 11
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 11: @1, src_ref: ('psuedo code file', 4, '@LCL')
# Machine step 12
# D: 53, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 12: D=M;null, src_ref: ('psuedo code file', 4, 'D=M')
# Machine step 13
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 13: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 14
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 14: A=M;null, src_ref: ('psuedo code file', 4, 'A=M')
# Machine step 15
# D: 0, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 15: M=D;null, src_ref: ('psuedo code file', 4, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 16
# D: 0, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 16: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 17
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 53] (stack)
# instr 17: M=M+1;null, src_ref: ('psuedo code file', 4, 'M=M+1')
# Machine step 18
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 18: @2, src_ref: ('psuedo code file', 4, '@ARG')
# Machine step 19
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 19: D=M;null, src_ref: ('psuedo code file', 4, 'D=M')
# Machine step 20
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 20: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 21
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 21: A=M;null, src_ref: ('psuedo code file', 4, 'A=M')
# Machine step 22
# D: 0, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 22: M=D;null, src_ref: ('psuedo code file', 4, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 23
# D: 0, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 23: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 24
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[253: M[SP]=258]: f[0, 0, 0, 53, 0] (stack)
# instr 24: M=M+1;null, src_ref: ('psuedo code file', 4, 'M=M+1')
# Machine step 25
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 25: @3, src_ref: ('psuedo code file', 4, '@THIS')
# Machine step 26
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 26: D=M;null, src_ref: ('psuedo code file', 4, 'D=M')
# Machine step 27
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 27: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 28
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 28: A=M;null, src_ref: ('psuedo code file', 4, 'A=M')
# Machine step 29
# D: 0, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 29: M=D;null, src_ref: ('psuedo code file', 4, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 30
# D: 0, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 30: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 31
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[254: M[SP]=259]: f[0, 0, 53, 0, 0] (stack)
# instr 31: M=M+1;null, src_ref: ('psuedo code file', 4, 'M=M+1')
# Machine step 32
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 32: @4, src_ref: ('psuedo code file', 4, '@THAT')
# Machine step 33
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 33: D=M;null, src_ref: ('psuedo code file', 4, 'D=M')
# Machine step 34
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 34: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 35
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 35: A=M;null, src_ref: ('psuedo code file', 4, 'A=M')
# Machine step 36
# D: 0, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 36: M=D;null, src_ref: ('psuedo code file', 4, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 37
# D: 0, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 37: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 38
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[255: M[SP]=260]: f[0, 53, 0, 0, 0] (stack)
# instr 38: M=M+1;null, src_ref: ('psuedo code file', 4, 'M=M+1')
# Machine step 39
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 39: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 40
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 40: D=M;null, src_ref: ('psuedo code file', 4, 'D=M')
# Machine step 41
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 41: @0, src_ref: ('psuedo code file', 4, '@0')
# Machine step 42
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 42: D=D-A;null, src_ref: ('psuedo code file', 4, 'D=D-A')
# Machine step 43
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 43: @5, src_ref: ('psuedo code file', 4, '@5')
# Machine step 44
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 44: D=D-A;null, src_ref: ('psuedo code file', 4, 'D=D-A')
# Machine step 45
# D: 256, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 45: @2, src_ref: ('psuedo code file', 4, '@ARG')
# Machine step 46
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 46: M=D;null, src_ref: ('psuedo code file', 4, 'M=D')
# Machine step 47
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 47: @0, src_ref: ('psuedo code file', 4, '@SP')
# Machine step 48
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 48: D=M;null, src_ref: ('psuedo code file', 4, 'D=M')
# Machine step 49
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 49: @1, src_ref: ('psuedo code file', 4, '@LCL')
# Machine step 50
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 50: M=D;null, src_ref: ('psuedo code file', 4, 'M=D')
# Machine step 51
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 51: @148, src_ref: ('psuedo code file', 4, '@Sys.init')
# Machine step 52
# D: 261, A: 148, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 52: null=0;JMP, src_ref: ('psuedo code file', 4, '0;JMP')
# Machine step 53
# D: 261, A: 148, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 148: @0, src_ref: ('vm_codes/test.vm', 7, '@0')
# Machine step 54
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 149: D=A;null, src_ref: ('vm_codes/test.vm', 7, 'D=A')
# Machine step 55
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 150: @0, src_ref: ('vm_codes/test.vm', 7, '@SP')
# Machine step 56
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 151: A=M;null, src_ref: ('vm_codes/test.vm', 7, 'A=M')
# Machine step 57
# D: 0, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 152: M=D;null, src_ref: ('vm_codes/test.vm', 7, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 58
# D: 0, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 153: @0, src_ref: ('vm_codes/test.vm', 7, '@SP')
# Machine step 59
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 154: M=M+1;null, src_ref: ('vm_codes/test.vm', 7, 'M=M+1')
# Machine step 60
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 155: @3, src_ref: ('vm_codes/test.vm', 13, '@3')
# Machine step 61
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 156: D=A;null, src_ref: ('vm_codes/test.vm', 13, 'D=A')
# Machine step 62
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 157: @0, src_ref: ('vm_codes/test.vm', 13, '@SP')
# Machine step 63
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 158: A=M;null, src_ref: ('vm_codes/test.vm', 13, 'A=M')
# Machine step 64
# D: 3, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 159: M=D;null, src_ref: ('vm_codes/test.vm', 13, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 65
# D: 3, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 160: @0, src_ref: ('vm_codes/test.vm', 13, '@SP')
# Machine step 66
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 161: M=M+1;null, src_ref: ('vm_codes/test.vm', 13, 'M=M+1')
# Machine step 67
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 162: @211, src_ref: ('vm_codes/test.vm', 14, '@1return-address')
# Machine step 68
# D: 3, A: 211, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 163: D=A;null, src_ref: ('vm_codes/test.vm', 14, 'D=A')
# Machine step 69
# D: 211, A: 211, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 164: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 70
# D: 211, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 165: A=M;null, src_ref: ('vm_codes/test.vm', 14, 'A=M')
# Machine step 71
# D: 211, A: 263, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 166: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 72
# D: 211, A: 263, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 167: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 73
# D: 211, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 3] (stack)
# instr 168: M=M+1;null, src_ref: ('vm_codes/test.vm', 14, 'M=M+1')
# Machine step 74
# D: 211, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 169: @1, src_ref: ('vm_codes/test.vm', 14, '@LCL')
# Machine step 75
# D: 211, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 170: D=M;null, src_ref: ('vm_codes/test.vm', 14, 'D=M')
# Machine step 76
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 171: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 77
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 172: A=M;null, src_ref: ('vm_codes/test.vm', 14, 'A=M')
# Machine step 78
# D: 261, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 173: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 79
# D: 261, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 174: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 80
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[259: M[SP]=264]: f[0, 0, 0, 3, 211] (stack)
# instr 175: M=M+1;null, src_ref: ('vm_codes/test.vm', 14, 'M=M+1')
# Machine step 81
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 176: @2, src_ref: ('vm_codes/test.vm', 14, '@ARG')
# Machine step 82
# D: 261, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 177: D=M;null, src_ref: ('vm_codes/test.vm', 14, 'D=M')
# Machine step 83
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 178: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 84
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 179: A=M;null, src_ref: ('vm_codes/test.vm', 14, 'A=M')
# Machine step 85
# D: 256, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 180: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 86
# D: 256, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 181: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 87
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[260: M[SP]=265]: f[0, 0, 3, 211, 261] (stack)
# instr 182: M=M+1;null, src_ref: ('vm_codes/test.vm', 14, 'M=M+1')
# Machine step 88
# D: 256, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 183: @3, src_ref: ('vm_codes/test.vm', 14, '@THIS')
# Machine step 89
# D: 256, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 184: D=M;null, src_ref: ('vm_codes/test.vm', 14, 'D=M')
# Machine step 90
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 185: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 91
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 186: A=M;null, src_ref: ('vm_codes/test.vm', 14, 'A=M')
# Machine step 92
# D: 0, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 187: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 93
# D: 0, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 188: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 94
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[261: M[SP]=266]: f[0, 3, 211, 261, 256] (stack)
# instr 189: M=M+1;null, src_ref: ('vm_codes/test.vm', 14, 'M=M+1')
# Machine step 95
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 190: @4, src_ref: ('vm_codes/test.vm', 14, '@THAT')
# Machine step 96
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 191: D=M;null, src_ref: ('vm_codes/test.vm', 14, 'D=M')
# Machine step 97
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 192: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 98
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 193: A=M;null, src_ref: ('vm_codes/test.vm', 14, 'A=M')
# Machine step 99
# D: 0, A: 267, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 194: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 100
# D: 0, A: 267, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 195: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 101
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[262: M[SP]=267]: f[3, 211, 261, 256, 0] (stack)
# instr 196: M=M+1;null, src_ref: ('vm_codes/test.vm', 14, 'M=M+1')
# Machine step 102
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 197: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 103
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 198: D=M;null, src_ref: ('vm_codes/test.vm', 14, 'D=M')
# Machine step 104
# D: 268, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 199: @1, src_ref: ('vm_codes/test.vm', 14, '@1')
# Machine step 105
# D: 268, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 200: D=D-A;null, src_ref: ('vm_codes/test.vm', 14, 'D=D-A')
# Machine step 106
# D: 267, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 201: @5, src_ref: ('vm_codes/test.vm', 14, '@5')
# Machine step 107
# D: 267, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 202: D=D-A;null, src_ref: ('vm_codes/test.vm', 14, 'D=D-A')
# Machine step 108
# D: 262, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 203: @2, src_ref: ('vm_codes/test.vm', 14, '@ARG')
# Machine step 109
# D: 262, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 204: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D')
# Machine step 110
# D: 262, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 205: @0, src_ref: ('vm_codes/test.vm', 14, '@SP')
# Machine step 111
# D: 262, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 206: D=M;null, src_ref: ('vm_codes/test.vm', 14, 'D=M')
# Machine step 112
# D: 268, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 207: @1, src_ref: ('vm_codes/test.vm', 14, '@LCL')
# Machine step 113
# D: 268, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 208: M=D;null, src_ref: ('vm_codes/test.vm', 14, 'M=D')
# Machine step 114
# D: 268, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 209: @55, src_ref: ('vm_codes/test.vm', 14, '@double')
# Machine step 115
# D: 268, A: 55, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 210: null=0;JMP, src_ref: ('vm_codes/test.vm', 14, '0;JMP')
# Machine step 116
# D: 268, A: 55, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 55: @0, src_ref: ('vm_codes/test.vm', 2, '@0')
# Machine step 117
# D: 268, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 56: D=A;null, src_ref: ('vm_codes/test.vm', 2, 'D=A')
# Machine step 118
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 57: @2, src_ref: ('vm_codes/test.vm', 2, '@ARG')
# Machine step 119
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 58: A=D+M;null, src_ref: ('vm_codes/test.vm', 2, 'A=D+M')
# Machine step 120
# D: 0, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 59: D=M;null, src_ref: ('vm_codes/test.vm', 2, 'D=M')
# Machine step 121
# D: 3, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 60: @0, src_ref: ('vm_codes/test.vm', 2, '@SP')
# Machine step 122
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 61: A=M;null, src_ref: ('vm_codes/test.vm', 2, 'A=M')
# Machine step 123
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 62: M=D;null, src_ref: ('vm_codes/test.vm', 2, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 124
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 63: @0, src_ref: ('vm_codes/test.vm', 2, '@SP')
# Machine step 125
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 64: M=M+1;null, src_ref: ('vm_codes/test.vm', 2, 'M=M+1')
# Machine step 126
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 65: @0, src_ref: ('vm_codes/test.vm', 3, '@0')
# Machine step 127
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 66: D=A;null, src_ref: ('vm_codes/test.vm', 3, 'D=A')
# Machine step 128
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 67: @2, src_ref: ('vm_codes/test.vm', 3, '@ARG')
# Machine step 129
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 68: A=D+M;null, src_ref: ('vm_codes/test.vm', 3, 'A=D+M')
# Machine step 130
# D: 0, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 69: D=M;null, src_ref: ('vm_codes/test.vm', 3, 'D=M')
# Machine step 131
# D: 3, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 70: @0, src_ref: ('vm_codes/test.vm', 3, '@SP')
# Machine step 132
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 71: A=M;null, src_ref: ('vm_codes/test.vm', 3, 'A=M')
# Machine step 133
# D: 3, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 72: M=D;null, src_ref: ('vm_codes/test.vm', 3, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 134
# D: 3, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 73: @0, src_ref: ('vm_codes/test.vm', 3, '@SP')
# Machine step 135
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 74: M=M+1;null, src_ref: ('vm_codes/test.vm', 3, 'M=M+1')
# Machine step 136
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[265: M[SP]=270]: f[256, 0, 0, 3, 3] (stack)
# instr 75: @0, src_ref: ('vm_codes/test.vm', 4, '@SP')
# Machine step 137
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[265: M[SP]=270]: f[256, 0, 0, 3, 3] (stack)
# instr 76: A=M-1;null, src_ref: ('vm_codes/test.vm', 4, 'A=M-1')
# Machine step 138
# D: 3, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[265: M[SP]=270]: f[256, 0, 0, 3, 3] (stack)
# instr 77: D=M;null, src_ref: ('vm_codes/test.vm', 4, 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 139
# D: 3, A: 269, M[16:20]: [0, 0, 0, 0] (static), M[265: M[SP]=270]: f[256, 0, 0, 3, 3] (stack)
# instr 78: @0, src_ref: ('vm_codes/test.vm', 4, '@SP')
# Machine step 140
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[265: M[SP]=270]: f[256, 0, 0, 3, 3] (stack)
# instr 79: M=M-1;null, src_ref: ('vm_codes/test.vm', 4, 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 141
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 80: @5, src_ref: ('vm_codes/test.vm', 4, '@5')
# Machine step 142
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 81: M=D;null, src_ref: ('vm_codes/test.vm', 4, 'M=D')
# Machine step 143
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 82: @0, src_ref: ('vm_codes/test.vm', 4, '@SP')
# Machine step 144
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 83: A=M-1;null, src_ref: ('vm_codes/test.vm', 4, 'A=M-1')
# Machine step 145
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 84: D=M;null, src_ref: ('vm_codes/test.vm', 4, 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 146
# D: 3, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 85: @0, src_ref: ('vm_codes/test.vm', 4, '@SP')
# Machine step 147
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 3] (stack)
# instr 86: M=M-1;null, src_ref: ('vm_codes/test.vm', 4, 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 148
# D: 3, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 87: @6, src_ref: ('vm_codes/test.vm', 4, '@6')
# Machine step 149
# D: 3, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 88: M=D;null, src_ref: ('vm_codes/test.vm', 4, 'M=D')
# Machine step 150
# D: 3, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 89: @5, src_ref: ('vm_codes/test.vm', 4, '@5')
# Machine step 151
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 90: D=M;null, src_ref: ('vm_codes/test.vm', 4, 'D=M')
# Machine step 152
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 91: @6, src_ref: ('vm_codes/test.vm', 4, '@6')
# Machine step 153
# D: 3, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 92: D=D+M;null, src_ref: ('vm_codes/test.vm', 4, 'D=D+M')
# Machine step 154
# D: 6, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 93: @0, src_ref: ('vm_codes/test.vm', 4, '@SP')
# Machine step 155
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 94: A=M;null, src_ref: ('vm_codes/test.vm', 4, 'A=M')
# Machine step 156
# D: 6, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 95: M=D;null, src_ref: ('vm_codes/test.vm', 4, 'M=D // M[M[SP]] is the tip of stack')
# Machine step 157
# D: 6, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 96: @0, src_ref: ('vm_codes/test.vm', 4, '@SP')
# Machine step 158
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 97: M=M+1;null, src_ref: ('vm_codes/test.vm', 4, 'M=M+1')
# Machine step 159
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 98: @1, src_ref: ('vm_codes/test.vm', 5, '@LCL')
# Machine step 160
# D: 6, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 99: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M')
# Machine step 161
# D: 268, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 100: @5, src_ref: ('vm_codes/test.vm', 5, '@5')
# Machine step 162
# D: 268, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 101: MD=D;null, src_ref: ('vm_codes/test.vm', 5, 'MD=D')
# Machine step 163
# D: 268, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 102: @5, src_ref: ('vm_codes/test.vm', 5, '@5')
# Machine step 164
# D: 268, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 103: A=D-A;null, src_ref: ('vm_codes/test.vm', 5, 'A=D-A // M[temp+0]-5')
# Machine step 165
# D: 268, A: 263, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 104: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M // M[M[temp+0]-5]')
# Machine step 166
# D: 211, A: 263, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 105: @6, src_ref: ('vm_codes/test.vm', 5, '@6')
# Machine step 167
# D: 211, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 106: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D')
# Machine step 168
# D: 211, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 107: @0, src_ref: ('vm_codes/test.vm', 5, '@SP')
# Machine step 169
# D: 211, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 108: A=M-1;null, src_ref: ('vm_codes/test.vm', 5, 'A=M-1')
# Machine step 170
# D: 211, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 109: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 171
# D: 6, A: 268, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 110: @0, src_ref: ('vm_codes/test.vm', 5, '@SP')
# Machine step 172
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[264: M[SP]=269]: f[261, 256, 0, 0, 6] (stack)
# instr 111: M=M-1;null, src_ref: ('vm_codes/test.vm', 5, 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 173
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 112: @2, src_ref: ('vm_codes/test.vm', 5, '@ARG')
# Machine step 174
# D: 6, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 113: A=M;null, src_ref: ('vm_codes/test.vm', 5, 'A=M')
# Machine step 175
# D: 6, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 114: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D // M[M[ARG]] = poped value')
# Machine step 176
# D: 6, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 115: @2, src_ref: ('vm_codes/test.vm', 5, '@ARG')
# Machine step 177
# D: 6, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 116: D=M+1;null, src_ref: ('vm_codes/test.vm', 5, 'D=M+1')
# Machine step 178
# D: 263, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 117: @0, src_ref: ('vm_codes/test.vm', 5, '@SP')
# Machine step 179
# D: 263, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[263: M[SP]=268]: f[211, 261, 256, 0, 0] (stack)
# instr 118: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D')
# Machine step 180
# D: 263, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 119: @5, src_ref: ('vm_codes/test.vm', 5, '@5')
# Machine step 181
# D: 263, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 120: A=M-1;null, src_ref: ('vm_codes/test.vm', 5, 'A=M-1')
# Machine step 182
# D: 263, A: 267, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 121: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M')
# Machine step 183
# D: 0, A: 267, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 122: @4, src_ref: ('vm_codes/test.vm', 5, '@THAT')
# Machine step 184
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 123: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D')
# Machine step 185
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 124: @2, src_ref: ('vm_codes/test.vm', 5, '@2')
# Machine step 186
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 125: D=A;null, src_ref: ('vm_codes/test.vm', 5, 'D=A')
# Machine step 187
# D: 2, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 126: @5, src_ref: ('vm_codes/test.vm', 5, '@5')
# Machine step 188
# D: 2, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 127: A=M-D;null, src_ref: ('vm_codes/test.vm', 5, 'A=M-D')
# Machine step 189
# D: 2, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 128: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M')
# Machine step 190
# D: 0, A: 266, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 129: @3, src_ref: ('vm_codes/test.vm', 5, '@THIS')
# Machine step 191
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 130: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D')
# Machine step 192
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 131: @3, src_ref: ('vm_codes/test.vm', 5, '@3')
# Machine step 193
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 132: D=A;null, src_ref: ('vm_codes/test.vm', 5, 'D=A')
# Machine step 194
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 133: @5, src_ref: ('vm_codes/test.vm', 5, '@5')
# Machine step 195
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 134: A=M-D;null, src_ref: ('vm_codes/test.vm', 5, 'A=M-D')
# Machine step 196
# D: 3, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 135: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M')
# Machine step 197
# D: 256, A: 265, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 136: @2, src_ref: ('vm_codes/test.vm', 5, '@ARG')
# Machine step 198
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 137: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D')
# Machine step 199
# D: 256, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 138: @4, src_ref: ('vm_codes/test.vm', 5, '@4')
# Machine step 200
# D: 256, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 139: D=A;null, src_ref: ('vm_codes/test.vm', 5, 'D=A')
# Machine step 201
# D: 4, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 140: @5, src_ref: ('vm_codes/test.vm', 5, '@5')
# Machine step 202
# D: 4, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 141: A=M-D;null, src_ref: ('vm_codes/test.vm', 5, 'A=M-D')
# Machine step 203
# D: 4, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 142: D=M;null, src_ref: ('vm_codes/test.vm', 5, 'D=M')
# Machine step 204
# D: 261, A: 264, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 143: @1, src_ref: ('vm_codes/test.vm', 5, '@LCL')
# Machine step 205
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 144: M=D;null, src_ref: ('vm_codes/test.vm', 5, 'M=D')
# Machine step 206
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 145: @6, src_ref: ('vm_codes/test.vm', 5, '@6')
# Machine step 207
# D: 261, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 146: A=M;null, src_ref: ('vm_codes/test.vm', 5, 'A=M')
# Machine step 208
# D: 261, A: 211, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 147: null=0;JMP, src_ref: ('vm_codes/test.vm', 5, '0;JMP')
# Machine step 209
# D: 261, A: 211, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 211: @0, src_ref: ('vm_codes/test.vm', 16, '@SP')
# Machine step 210
# D: 261, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 212: A=M-1;null, src_ref: ('vm_codes/test.vm', 16, 'A=M-1')
# Machine step 211
# D: 261, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 213: D=M;null, src_ref: ('vm_codes/test.vm', 16, 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 212
# D: 6, A: 262, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 214: @0, src_ref: ('vm_codes/test.vm', 16, '@SP')
# Machine step 213
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[258: M[SP]=263]: f[0, 0, 0, 0, 6] (stack)
# instr 215: M=M-1;null, src_ref: ('vm_codes/test.vm', 16, 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 214
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 216: @5, src_ref: ('vm_codes/test.vm', 16, '@5')
# Machine step 215
# D: 6, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 217: M=D;null, src_ref: ('vm_codes/test.vm', 16, 'M=D')
# Machine step 216
# D: 6, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 218: @0, src_ref: ('vm_codes/test.vm', 16, '@0')
# Machine step 217
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 219: D=A;null, src_ref: ('vm_codes/test.vm', 16, 'D=A')
# Machine step 218
# D: 0, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 220: @1, src_ref: ('vm_codes/test.vm', 16, '@LCL')
# Machine step 219
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 221: D=D+M;null, src_ref: ('vm_codes/test.vm', 16, 'D=D+M // M[LCL]+index')
# Machine step 220
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 222: @6, src_ref: ('vm_codes/test.vm', 16, '@6')
# Machine step 221
# D: 261, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 223: M=D;null, src_ref: ('vm_codes/test.vm', 16, 'M=D // temp[1] = M[LCL]+index')
# Machine step 222
# D: 261, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 224: @5, src_ref: ('vm_codes/test.vm', 16, '@5')
# Machine step 223
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 225: D=M;null, src_ref: ('vm_codes/test.vm', 16, 'D=M // retrieve saved top')
# Machine step 224
# D: 6, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 226: @6, src_ref: ('vm_codes/test.vm', 16, '@6')
# Machine step 225
# D: 6, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 227: A=M;null, src_ref: ('vm_codes/test.vm', 16, 'A=M')
# Machine step 226
# D: 6, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 0] (stack)
# instr 228: M=D;null, src_ref: ('vm_codes/test.vm', 16, 'M=D')
# Machine step 227
# D: 6, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 229: @1, src_ref: ('vm_codes/test.vm', 17, '@LCL')
# Machine step 228
# D: 6, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 230: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M')
# Machine step 229
# D: 261, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 231: @5, src_ref: ('vm_codes/test.vm', 17, '@5')
# Machine step 230
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 232: MD=D;null, src_ref: ('vm_codes/test.vm', 17, 'MD=D')
# Machine step 231
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 233: @5, src_ref: ('vm_codes/test.vm', 17, '@5')
# Machine step 232
# D: 261, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 234: A=D-A;null, src_ref: ('vm_codes/test.vm', 17, 'A=D-A // M[temp+0]-5')
# Machine step 233
# D: 261, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 235: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M // M[M[temp+0]-5]')
# Machine step 234
# D: 53, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 236: @6, src_ref: ('vm_codes/test.vm', 17, '@6')
# Machine step 235
# D: 53, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 237: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D')
# Machine step 236
# D: 53, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 238: @0, src_ref: ('vm_codes/test.vm', 17, '@SP')
# Machine step 237
# D: 53, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 239: A=M-1;null, src_ref: ('vm_codes/test.vm', 17, 'A=M-1')
# Machine step 238
# D: 53, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 240: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M // D=M[M[SP]-1] that is stack.top()')
# Machine step 239
# D: 6, A: 261, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 241: @0, src_ref: ('vm_codes/test.vm', 17, '@SP')
# Machine step 240
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[257: M[SP]=262]: f[0, 0, 0, 0, 6] (stack)
# instr 242: M=M-1;null, src_ref: ('vm_codes/test.vm', 17, 'M=M-1 // M[SP] -= 1 // D=stack.pop()')
# Machine step 241
# D: 6, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 243: @2, src_ref: ('vm_codes/test.vm', 17, '@ARG')
# Machine step 242
# D: 6, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 244: A=M;null, src_ref: ('vm_codes/test.vm', 17, 'A=M')
# Machine step 243
# D: 6, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[53, 0, 0, 0, 0] (stack)
# instr 245: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D // M[M[ARG]] = poped value')
# Machine step 244
# D: 6, A: 256, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[6, 0, 0, 0, 0] (stack)
# instr 246: @2, src_ref: ('vm_codes/test.vm', 17, '@ARG')
# Machine step 245
# D: 6, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[6, 0, 0, 0, 0] (stack)
# instr 247: D=M+1;null, src_ref: ('vm_codes/test.vm', 17, 'D=M+1')
# Machine step 246
# D: 257, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[6, 0, 0, 0, 0] (stack)
# instr 248: @0, src_ref: ('vm_codes/test.vm', 17, '@SP')
# Machine step 247
# D: 257, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[256: M[SP]=261]: f[6, 0, 0, 0, 0] (stack)
# instr 249: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D')
# Machine step 248
# D: 257, A: 0, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 250: @5, src_ref: ('vm_codes/test.vm', 17, '@5')
# Machine step 249
# D: 257, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 251: A=M-1;null, src_ref: ('vm_codes/test.vm', 17, 'A=M-1')
# Machine step 250
# D: 257, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 252: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M')
# Machine step 251
# D: 0, A: 260, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 253: @4, src_ref: ('vm_codes/test.vm', 17, '@THAT')
# Machine step 252
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 254: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D')
# Machine step 253
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 255: @2, src_ref: ('vm_codes/test.vm', 17, '@2')
# Machine step 254
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 256: D=A;null, src_ref: ('vm_codes/test.vm', 17, 'D=A')
# Machine step 255
# D: 2, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 257: @5, src_ref: ('vm_codes/test.vm', 17, '@5')
# Machine step 256
# D: 2, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 258: A=M-D;null, src_ref: ('vm_codes/test.vm', 17, 'A=M-D')
# Machine step 257
# D: 2, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 259: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M')
# Machine step 258
# D: 0, A: 259, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 260: @3, src_ref: ('vm_codes/test.vm', 17, '@THIS')
# Machine step 259
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 261: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D')
# Machine step 260
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 262: @3, src_ref: ('vm_codes/test.vm', 17, '@3')
# Machine step 261
# D: 0, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 263: D=A;null, src_ref: ('vm_codes/test.vm', 17, 'D=A')
# Machine step 262
# D: 3, A: 3, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 264: @5, src_ref: ('vm_codes/test.vm', 17, '@5')
# Machine step 263
# D: 3, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 265: A=M-D;null, src_ref: ('vm_codes/test.vm', 17, 'A=M-D')
# Machine step 264
# D: 3, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 266: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M')
# Machine step 265
# D: 0, A: 258, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 267: @2, src_ref: ('vm_codes/test.vm', 17, '@ARG')
# Machine step 266
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 268: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D')
# Machine step 267
# D: 0, A: 2, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 269: @4, src_ref: ('vm_codes/test.vm', 17, '@4')
# Machine step 268
# D: 0, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 270: D=A;null, src_ref: ('vm_codes/test.vm', 17, 'D=A')
# Machine step 269
# D: 4, A: 4, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 271: @5, src_ref: ('vm_codes/test.vm', 17, '@5')
# Machine step 270
# D: 4, A: 5, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 272: A=M-D;null, src_ref: ('vm_codes/test.vm', 17, 'A=M-D')
# Machine step 271
# D: 4, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 273: D=M;null, src_ref: ('vm_codes/test.vm', 17, 'D=M')
# Machine step 272
# D: 0, A: 257, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 274: @1, src_ref: ('vm_codes/test.vm', 17, '@LCL')
# Machine step 273
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 275: M=D;null, src_ref: ('vm_codes/test.vm', 17, 'M=D')
# Machine step 274
# D: 0, A: 1, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 276: @6, src_ref: ('vm_codes/test.vm', 17, '@6')
# Machine step 275
# D: 0, A: 6, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 277: A=M;null, src_ref: ('vm_codes/test.vm', 17, 'A=M')
# Machine step 276
# D: 0, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 278: null=0;JMP, src_ref: ('vm_codes/test.vm', 17, '0;JMP')
# Machine step 277
# D: 0, A: 53, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 53: @279, src_ref: ('psuedo code file', 5, '@0END')
# Machine step 278
# D: 0, A: 279, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# instr 54: null=0;JMP, src_ref: ('psuedo code file', 6, '0;JMP')
# Machine step 279
# D: 0, A: 279, M[16:20]: [0, 0, 0, 0] (static), M[252: M[SP]=257]: f[0, 0, 0, 0, 6] (stack)
# Finished execution
# Symbol table after execution
# ==============================
# Assembler(free_address=16, symbol_table=
# symbol    |address
# ---------------------
# SP        |0
# LCL       |1
# ARG       |2
# THIS      |3
# THAT      |4
# SCREEN    |16384
# KBD       |24576
# R0        |0
# R1        |1
# R2        |2
# R3        |3
# R4        |4
# R5        |5
# R6        |6
# R7        |7
# R8        |8
# R9        |9
# R10       |10
# R11       |11
# R12       |12
# R13       |13
# R14       |14
# R15       |15
# 0return-address|53
# double    |55
# Sys.init  |148
# 1return-address|211
# 0END      |279
# )
